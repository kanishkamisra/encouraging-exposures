# %%
import json
import utils

from collections import defaultdict, Counter

# %%
adaptation = utils.read_jsonl("../data/experiments/single_stimuli_dative_simulation_valtest_vbd_no_discourse/adaptation.jsonl")

# %%
'''
Canonical marking rules:

if pronoun and pronoun: canonically unmarked
if pronoun and proper noun: 
if theme = pronoun and recipient = full NP = non canonically marked
if theme = full NP and recipient = pronoun = canonically marked
if full NP and fill NP with canonicality both = same = canonically unmarked
if full NP and full NP with canonicality of one not the same as the other = canonically marked
'''

# %%
adaptation
# Out:
# [{'item': 1,
#   'hypothesis_id': 1,
#   'hypothesis_instance': 1,
#   'theme_pronominality': 'pronoun',
#   'theme_animacy': 'animate',
#   'theme_length': 'short',
#   'theme_definiteness': 'definite',
#   'theme_canonicality': 'unmarked',
#   'recipient_pronominality': 'pronoun',
#   'recipient_animacy': 'animate',
#   'recipient_length': 'short',
#   'recipient_definiteness': 'definite',
#   'recipient_canonicality': 'unmarked',
#   'agent': 'mommy',
#   'theme': 'me',
#   'recipient': 'her',
#   'dative': 'do',
#   'sentence': 'mommy [verb] her me .'},
#  {'item': 2,
#   'hypothesis_id': 1,
#   'hypothesis_instance': 2,
#   'theme_pronominality': 'pronoun',
#   'theme_animacy': 'animate',
#   'theme_length': 'short',
#   'theme_definiteness': 'definite',
#   'theme_canonicality': 'unmarked',
#   'recipient_pronominality': 'pronoun',
#   'recipient_animacy': 'animate',
#   'recipient_length': 'short',
#   'recipient_definiteness': 'definite',
# ...
