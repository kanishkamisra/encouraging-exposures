# %%
import spacy
import utils
import re

from collections import defaultdict, Counter
from minicons.utils import get_batch
from tqdm import tqdm

# %%
# spacy setup
gpu = spacy.prefer_gpu(2)
nlp = spacy.load("en_core_web_trf")

# %%
# aochildes
corpus = utils.read_file("../../smolm/data/corpora/babylm_data/babylm_100M/aochildes.train")

# %%
alternating_verbs = '''feed,give,lease,lend,loan,pass,pay,peddle,refund,render,rent,repay,sell,serve,trade,advance,allocate,allot,assign,award,bequeath,cede,concede,extend,grant,guarantee,issue,leave,offer,owe,promise,vote,will,yield,bring,take,forward,hand,mail,post,send,ship,slip,smuggle,sneak,bounce,float,roll,slide,carry,drag,haul,heave,heft,hoise,kick,lug,pull,push,schlep,shove,tote,tow,tug,barge,bus,cart,drive,ferry,fly,row,shuttle,truck,wheel,wire,bash,bat,bunt,catapult,chuck,flick,fling,flip,hit,hurl,kick,lob,pass,pitch,punt,shoot,shove,slam,slap,sling,throw,tip,toss,ask,cite,pose,preach,quote,read,relay,show,teach,tell,write,cable,email,e-mail,fax,modem,netmail,phone,radio,relay,satellite,semaphore,sign,signal,telephone,telecast,telegraph,telex,wire,wireless'''.split(",")

do_only_verbs = '''accord,ask,bear,begrudge,bode,cost,deny,envy,flash,forbid,forgive,guarantee,issue,refuse,save,spare,strike,vouchsafe,wish,write,bet,bill,charge,fine,mulct,overcharge,save,spare,tax,tip,undercharge,wager,acknowledge,adopt,appoint,consider,crown,deem,designate,elect,esteeem,imagine,mark,nominate,ordain,proclaim,rate,recon,report,want,anoint,baptize,brand,call,christen,consecrate,crown,decree,dub,label,make,name,nickname,pronounce,rule,stamp,style,term,vote,adjudge,adjudicate,assume,avow,believe,confess,declare,fancy,find,judge,presume,profess,prove,suppose,think,warrant'''.split(",")

pp_only_verbs = '''address,administer,broadcast,convey,contribute,delegate,deliver,denounce,demonstrate,describe,dictate,dispatch,display,distribute,donate,elucidate,exhibit,express,explain,explicate,forfeit,illustrate,introduce,narrate,portray,proffer,recite,recommend,refer,reimburse,remit,restore,return,sacrifice,submit,surrender,transfer,transport,admit,allege,announce,articulate,assert,communicate,confess,convey,declare,mention,propose,recount,repeat,report,reveal,say,state,babble,bark,bawl,bellow,bleat,boom,bray,burble,cackle,call,carol,chant,chatter,chrip,cluck,coo,croak,croon,crow,cry,drawl,drone,gabble,gibber,groan,growl,grumble,grunt,hiss,holler,hoot,howl,jabber,lilt,lisp,moan,mumble,murmur,mutter,purr,rage,rasp,roar,rumble,scream,screech,shout,shriek,sing,snap,snarl,snuffle,splutter,squall,squawk,squeak,squeal,stammer,stutter,thunder,tisk,trill,trumpet,twitter,wail,warble,wheeze,whimper,whine,whisper,whistle,whoop,yammer,yap,yell,yelp,yodel,drop,hoist,lift,lower,raise,credit,entrust,furnish,issue,leave,present,provide,serve,supply,trust'''.split(",")

# %%
dative_verbs = sorted(list(set(alternating_verbs + do_only_verbs + pp_only_verbs)))

# %%
def get_postags(texts, batch_size, processor):
    taglist = []
    for doc in tqdm(processor.pipe(texts, disable=["tok2vec", "parser", "attribute_ruler", "lemmatizer", "ner"], batch_size=batch_size)):
        sentlist = []
        for entity in doc:
            sentlist += [(entity.text, entity.tag_)]
        taglist += [sentlist]
    return taglist

# recursively get children of a verb using spacy
def get_children_flatten(token, depth=0, dep=False, return_tokens=False):
    children = []
    for child in token.children:
        if dep:
            if return_tokens:
                children.append((child.text.lower(), child.dep_, child.tag_, depth, child.i, child))
            else:
                children.append((child.text.lower(), child.dep_, child.tag_, depth, child.i))
        else:
            children.append(child.text.lower())
        children.extend(get_children_flatten(child, depth+1, dep, return_tokens))
    return children

def collect_args(children_obj, hyp = 'do'):
    args = {'theme': '', 'recipient': '', 'theme_pos': '', 'recipient_pos': ''}
    hyp_args = []
    if hyp == "do":
        for child in children_obj:
            if child[1] == "dobj" or child[1] == "dative":
                hyp_args.append((child[0], child[-1], child[2]))
        
        # sort by index
        hyp_args = sorted(hyp_args, key=lambda x: x[1])
        args['recipient'] = hyp_args[0][0]
        args['theme'] = hyp_args[1][0]
        args['recipient_pos'] = hyp_args[0][-1]
        args['theme_pos'] = hyp_args[1][-1]

    elif hyp == "pp":
        for child in children_obj:
            if child[1] == "pobj" or child[1] == "dobj":
                hyp_args.append((child[0], child[-1], child[2]))
        
        # sort by index
        hyp_args = sorted(hyp_args, key=lambda x: x[1])
        args['recipient'] = hyp_args[1][0]
        args['theme'] = hyp_args[0][0]
        args['recipient_pos'] = hyp_args[1][-1]
        args['theme_pos'] = hyp_args[0][-1]

    return args

def get_datives(texts, batch_size, processor):
    dos, pps = [], []
    for doc in tqdm(processor.pipe(texts, disable = ["ner"], batch_size = batch_size)):
        do = False
        pp = False
        for entity in doc:
            if entity.pos_ == "VERB":
                children = get_children_flatten(entity, 0, dep=True)
                if len(children) > 0:
                    tokens, dep, pos_string, depth, index = list(zip(*children))
                    if "to" in tokens:
                        # possibility for pp
                        dep_depth = [f"{d}_{str(depth[i])}" for i, d in enumerate(dep)]
                        tok_dep = [f"{tokens[i]}_{dep[i]}" for i in range(len(tokens))]
                        if ("dobj_0" in dep_depth and "dative_0" in dep_depth and "pobj_1" in dep_depth) or ("dobj_0" in dep_depth and "prep_0" in dep_depth and "pobj_1" in dep_depth):
                            if "to_dative" in tok_dep or "to_prep" in tok_dep:
                                pp = True
                                # pps.append(sentence)
                                # print(children)
                                # args = collect_args(children, "pp")
                                pps.append((doc.text, entity.lemma_, entity.text, entity.tag_, children))
                                break
                    else:
                        # possibility for DO
                        # concatenation of dep and depth
                        dep_depth = [f"{d}_{str(depth[i])}" for i, d in enumerate(dep)]
                        tokens_dep = [f"{tokens[i]}_{dep[i]}" for i in range(len(tokens))]
                        if ("dobj_0" in dep_depth and "dative_0" in dep_depth) or Counter(dep_depth)['dobj_0'] >= 2:
                            if 'for_dative' not in tokens_dep and 'for_dobj' not in tokens_dep:
                                do = True
                                # dos.append(sentence)
                                # print(children)
                                # args = collect_args(children)
                                dos.append((doc.text, entity.lemma_, entity.text, entity.tag_, children))
                                break

    return dos, pps

# %%
do_examples = [
    "she gave me the ball.",
    "she gave mom the ball.",
    "she sent grandma the big book.",
    "she is tossing the dog the big ball.",
    "she had given me the ball.",
    "she has given mommy the ball.",
]

pp_examples = [
    "she gave the ball to me.",
    "she gave the ball to mom.",
    "she sent the big book to grandma.",
    "she is tossing the big ball to the dog.",
    "she had given the ball to me.",
    "she gave it to me.",
    "she had given it to mommy yesterday morning.",
    "slap the cheese on it so the cheese starts to melt ."
]

test_corpus = do_examples + pp_examples

DOS_test, PPS_test = [], []
for batch in get_batch(test_corpus, batch_size=6):
    dos, pps = get_datives(batch, 6, nlp)
    DOS_test.extend(dos)
    PPS_test.extend(pps)
# Out:
# 6it [00:01,  4.07it/s]
# 6it [00:00, 347.45it/s]
# 2it [00:00, 167.22it/s]

# %%
# DOS_test, PPS_test
len(PPS_test)
# Out:
# 7

# %%
DOS, PPS = [], []
for batch in get_batch(corpus, batch_size=8192):
    dos, pps = get_datives(batch, 8192, nlp)
    DOS.extend(dos)
    PPS.extend(pps)
# Out:
# 0it [00:00, ?it/s]
# 8192it [00:06, 1307.49it/s]
# 8192it [00:05, 1374.28it/s]
# 8192it [00:05, 1423.86it/s]
# 8192it [00:05, 1372.44it/s]
# 8192it [00:04, 1641.78it/s]
# 8192it [00:05, 1373.45it/s]
# 8192it [00:05, 1575.72it/s]
# 8192it [00:05, 1608.96it/s]
# 8192it [00:05, 1577.71it/s]
# 8192it [00:05, 1512.57it/s]
# 8192it [00:05, 1488.35it/s]
# 8192it [00:05, 1427.51it/s]
# 8192it [00:05, 1513.67it/s]
# 8192it [00:05, 1432.42it/s]
# 8192it [00:05, 1448.38it/s]
# 8192it [00:05, 1589.01it/s]
# 8192it [00:05, 1485.13it/s]
# 8192it [00:05, 1456.86it/s]
# 8192it [00:05, 1425.13it/s]
# 8192it [00:05, 1495.01it/s]
# 8192it [00:05, 1488.73it/s]
# 8192it [00:05, 1546.36it/s]
# 8192it [00:05, 1615.41it/s]
# 8192it [00:05, 1518.49it/s]
# 8192it [00:05, 1587.99it/s]
# 8192it [00:05, 1432.78it/s]
# 8192it [00:05, 1607.56it/s]
# 8192it [00:05, 1501.56it/s]
# 8192it [00:05, 1511.95it/s]
# 8192it [00:05, 1458.69it/s]
# 8192it [00:05, 1455.94it/s]
# 8192it [00:05, 1511.99it/s]
# 8192it [00:05, 1482.04it/s]
# 8192it [00:05, 1489.87it/s]
# 8192it [00:05, 1436.98it/s]
# 8192it [00:05, 1508.05it/s]
# 8192it [00:05, 1472.70it/s]
# 8192it [00:05, 1475.39it/s]
# 8192it [00:05, 1418.26it/s]
# 8192it [00:05, 1493.03it/s]
# 8192it [00:05, 1457.13it/s]
# 8192it [00:05, 1434.14it/s]
# 8192it [00:05, 1495.24it/s]
# 8192it [00:05, 1452.47it/s]
# 8192it [00:05, 1495.25it/s]
# 8192it [00:05, 1550.04it/s]
# 8192it [00:05, 1529.02it/s]
# 8192it [00:05, 1406.87it/s]
# 8192it [00:05, 1474.07it/s]
# 8192it [00:05, 1471.70it/s]
# 8192it [00:05, 1449.87it/s]
# 8192it [00:05, 1400.93it/s]
# 8192it [00:05, 1441.74it/s]
# 8192it [00:05, 1438.68it/s]
# 8192it [00:05, 1567.61it/s]
# 8192it [00:05, 1533.20it/s]
# 8192it [00:05, 1511.79it/s]
# 8192it [00:05, 1372.19it/s]
# 8192it [00:05, 1419.89it/s]
# 8192it [00:05, 1509.71it/s]
# 8192it [00:05, 1466.58it/s]
# 8192it [00:05, 1458.59it/s]
# 8192it [00:05, 1394.81it/s]
# 8192it [00:05, 1480.39it/s]
# 8192it [00:05, 1451.83it/s]
# 8192it [00:05, 1460.46it/s]
# 8192it [00:05, 1458.11it/s]
# 8192it [00:05, 1411.81it/s]
# 8192it [00:05, 1446.64it/s]
# 8192it [00:05, 1439.65it/s]
# 8192it [00:05, 1473.08it/s]
# 8192it [00:05, 1484.20it/s]
# 8192it [00:05, 1525.00it/s]
# 8192it [00:05, 1452.31it/s]
# 8192it [00:05, 1557.07it/s]
# 8192it [00:05, 1483.93it/s]
# 8192it [00:05, 1434.83it/s]
# 8192it [00:05, 1483.65it/s]
# 8192it [00:05, 1431.37it/s]
# 8192it [00:05, 1499.49it/s]
# 8192it [00:05, 1438.33it/s]
# 8192it [00:05, 1497.29it/s]
# 8192it [00:05, 1468.59it/s]
# 8192it [00:05, 1435.21it/s]
# 8192it [00:05, 1447.03it/s]
# 8192it [00:06, 1346.97it/s]
# 8192it [00:05, 1436.92it/s]
# 8192it [00:05, 1436.67it/s]
# 8192it [00:05, 1442.66it/s]
# 8192it [00:05, 1496.96it/s]
# 8192it [00:05, 1367.12it/s]
# 8192it [00:05, 1387.55it/s]
# 8192it [00:06, 1196.41it/s]
# 2133it [00:01, 1377.30it/s]

# %%
len(DOS), len(PPS)
# Out:
# (8172, 4102)

# %%
DOS_FILTERED, PPS_FILTERED = [], []

DOS_DISCARDED, PPS_DISCARDED = [], []

for sentence, lemma, verb, verb_pos, children in DOS:
    if lemma in dative_verbs:
        args = collect_args(children)
        # if args['theme_pos'] in ['NN', 'NNS', 'NNP', 'PRP', 'DT'] and args['recipient_pos'] in ['NN', 'NNS', 'NNP', 'PRP']:
        #     DOS_FILTERED.append((sentence, lemma, verb, args['theme'], args['recipient']))
        # else:
        #     DOS_DISCARDED.append((sentence, lemma, verb, args['theme'], args['recipient'], args['theme_pos'], args['recipient_pos']))

        DOS_FILTERED.append((sentence, lemma, verb, verb_pos, args['theme'], args['recipient'], args['theme_pos'], args['recipient_pos']))

for sentence, lemma, verb, verb_pos, children in PPS:
    if lemma in dative_verbs:
        args = collect_args(children, "pp")
        # tag = children[2]
        # if args['theme_pos'] in ['NN', 'NNS', 'NNP', 'PRP', 'DT'] and args['recipient_pos'] in ['NN', 'NNS', 'NNP', 'PRP']:
        #     PPS_FILTERED.append((sentence, lemma, verb, args['theme'], args['recipient']))
        # else:
        #     PPS_DISCARDED.append((sentence, lemma, verb, args['theme'], args['recipient'], args['theme_pos'], args['recipient_pos']))
        PPS_FILTERED.append((sentence, lemma, verb, verb_pos, args['theme'], args['recipient'], args['theme_pos'], args['recipient_pos']))

# %%
len(DOS_FILTERED), len(PPS_FILTERED)
# Out:
# (6181, 3075)

# %%
# write both to csv in data/
import csv

with open("../data/aochildes_dos.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerow(["sentence", "lemma", "verb", "verb_pos", "theme", "recipient", "theme_pos", "recipient_pos"])
    writer.writerows(DOS_FILTERED)

with open("../data/aochildes_pps.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerow(["sentence", "lemma", "verb", "verb_pos", "theme", "recipient", "theme_pos", "recipient_pos"])
    writer.writerows(PPS_FILTERED)

# %%
PPS_DISCARDED
# Out:
# [('who are you reading them to ?',
#   'read',
#   'reading',
#   'who',
#   'them',
#   'WP',
#   'PRP'),
#  ("are you going to tell her about all you've done today .",
#   'tell',
#   'tell',
#   'her',
#   'all',
#   'PRP',
#   'DT'),
#  ('okay try not to make a mess with this .',
#   'make',
#   'make',
#   'mess',
#   'this',
#   'NN',
#   'DT'),
#  ('is that what they said to you ?',
#   'say',
#   'said',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ('thomas is coming to say hello to us .',
#   'say',
#   'say',
#   'hello',
#   'us',
#   'UH',
#   'PRP'),
#  ('so that brings it down to four .',
#   'bring',
#   'brings',
#   'it',
#   'four',
#   'PRP',
#   'CD'),
#  ('mm what do you say to grandma ?',
#   'say',
#   'say',
#   'what',
#   'grandma',
#   'WP',
#   'NN'),
#  ('oh thank you are you giving that to mommy ?',
#   'give',
#   'giving',
#   'you',
#   'that',
#   'PRP',
#   'DT'),
#  ('what are you saying to me my friend ?',
#   'say',
#   'saying',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('you want to give some of those to your papa ?',
#   'give',
#   'give',
#   'some',
#   'those',
#   'DT',
#   'DT'),
#  ('hello you want mommy to say hello on this one .',
#   'say',
#   'say',
#   'hello',
#   'one',
#   'UH',
#   'NN'),
#  ("this kid doesn't know what to think of it .",
#   'think',
#   'think',
#   'what',
#   'it',
#   'WP',
#   'PRP'),
#  ('what does that dog say to john ?',
#   'say',
#   'say',
#   'what',
#   'john',
#   'WP',
#   'NNP'),
#  ("what's the kitty cat say to john ?",
#   'say',
#   'say',
#   'what',
#   'john',
#   'WP',
#   'NNP'),
#  ("we'll say goodbye to the yucky .",
#   'say',
#   'say',
#   'goodbye',
#   'yucky',
#   'UH',
#   'NNP'),
#  ('you wanna feed one to baby kate honey ?',
#   'feed',
#   'feed',
#   'one',
#   'honey',
#   'CD',
#   'NNP'),
#  ("oh you're feeding one to the tree .",
#   'feed',
#   'feeding',
#   'one',
#   'tree',
#   'CD',
#   'NN'),
#  ("why don't you feed one to duckie ?",
#   'feed',
#   'feed',
#   'one',
#   'duckie',
#   'CD',
#   'NN'),
#  ('what about lala you wanna feed some to lala ?',
#   'feed',
#   'feed',
#   'lala',
#   'some',
#   'NNP',
#   'DT'),
#  ('who are you giving those to ?',
#   'give',
#   'giving',
#   'who',
#   'those',
#   'WP',
#   'DT'),
#  ('would you like me to come in and say hello to you ?',
#   'say',
#   'say',
#   'hello',
#   'you',
#   'UH',
#   'PRP'),
#  ('this is may fifteenth and what have you had to say to the tape recorder .',
#   'say',
#   'say',
#   'what',
#   'recorder',
#   'WP',
#   'NN'),
#  ('who are you giving it to ?', 'give', 'giving', 'who', 'it', 'WP', 'PRP'),
#  ("okay i don't know what else to say about rossy .",
#   'say',
#   'say',
#   'what',
#   'rossy',
#   'WP',
#   'NNP'),
#  ('that is what i wanted you to say about the glass .',
#   'say',
#   'say',
#   'what',
#   'glass',
#   'WP',
#   'NN'),
#  ('so wha dijou say to them .', 'say', 'say', 'wha', 'them', 'WP', 'PRP'),
#  ('can i feed one to the kittie .',
#   'feed',
#   'feed',
#   'one',
#   'kittie',
#   'CD',
#   'NN'),
#  ('you want you wanna throw that away should we bring that to the garbage can ?',
#   'bring',
#   'bring',
#   'that',
#   'that',
#   'DT',
#   'DT'),
#  ('well there was a man who had a rope on the boat that we took ff from bar harbor to winter harbor .',
#   'take',
#   'took',
#   'that',
#   'ff',
#   'WDT',
#   'NNP'),
#  ('what do you want daddy to bring home for you ?',
#   'bring',
#   'bring',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ('who should we sing happy birthday to ?',
#   'sing',
#   'sing',
#   'who',
#   'birthday',
#   'WP',
#   'NN'),
#  ('what did the dirt say to the rain ?',
#   'say',
#   'say',
#   'what',
#   'rain',
#   'WP',
#   'NN'),
#  ('what did the hippie say to the invisible man ?',
#   'say',
#   'say',
#   'what',
#   'man',
#   'WP',
#   'NN'),
#  ('and he likes oh and i was giving his bottle to the .',
#   'give',
#   'giving',
#   'bottle',
#   'the',
#   'NN',
#   'DT'),
#  ('bring floppy to mommy .', 'bring', 'bring', 'floppy', 'mommy', 'JJ', 'NN'),
#  ("someone said to me the other she was doing it the other day and they were like god she grunts a lot i'm like what do you mean she grunts and they were like she's always going uh eh and i was like is that a grunt yeah she does that all day ?",
#   'say',
#   'said',
#   'me',
#   'other',
#   'PRP',
#   'JJ'),
#  ("what's the coat wax saying to you ?",
#   'say',
#   'saying',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ('what do you say to daddy when he goes to work in the morning .',
#   'say',
#   'say',
#   'what',
#   'daddy',
#   'WP',
#   'NN'),
#  ("he's usually wagging his tail n' looking to say hello to people .",
#   'say',
#   'say',
#   'hello',
#   'people',
#   'UH',
#   'NNS'),
#  ("that's a piece of crayon why don't you give that to me cause it's too small .",
#   'give',
#   'give',
#   'crayon',
#   'that',
#   'NN',
#   'DT'),
#  ('would you like to tell me about this again .',
#   'tell',
#   'tell',
#   'me',
#   'this',
#   'PRP',
#   'DT'),
#  ('what do you say to mommy ?', 'say', 'say', 'what', 'mommy', 'WP', 'NN'),
#  ('what do you say to mommy ?', 'say', 'say', 'what', 'mommy', 'WP', 'NN'),
#  ('what do you say to your mommy ?',
#   'say',
#   'say',
#   'what',
#   'mommy',
#   'WP',
#   'NN'),
#  ("what's grandma saying to you ?",
#   'say',
#   'saying',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ('okay tell jessica what you said to me the other day ?',
#   'say',
#   'said',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('and what did bert have to say about that .',
#   'say',
#   'say',
#   'what',
#   'that',
#   'WP',
#   'DT'),
#  ("and we'll see what she says to us .",
#   'say',
#   'says',
#   'what',
#   'us',
#   'WP',
#   'PRP'),
#  ('take it to the .', 'take', 'take', 'it', 'the', 'PRP', 'DT'),
#  ('you wanna take off your costume for now looks like one antenna is falling off yeah i can take those out for little while we can put them back on when we are ready to go to the library oh you took it out for me okay you wanna give that to me okay ?',
#   'take',
#   'took',
#   'costume',
#   'those',
#   'NN',
#   'DT'),
#  ('what would you like me to read to you ?',
#   'read',
#   'read',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ('would you say goodbye to the ball .',
#   'say',
#   'say',
#   'goodbye',
#   'ball',
#   'UH',
#   'NN'),
#  ("you'll have to ask daddy about that .",
#   'ask',
#   'ask',
#   'daddy',
#   'that',
#   'NN',
#   'DT'),
#  ('today will give one of my strawberries to laura .',
#   'give',
#   'give',
#   'one',
#   'strawberries',
#   'CD',
#   'NNS'),
#  ("i that's what i said to him right when he came down the stairs .",
#   'say',
#   'said',
#   'what',
#   'him',
#   'WP',
#   'PRP'),
#  ('see so that when you go to fix things you carry this around with you !',
#   'carry',
#   'carry',
#   'things',
#   'this',
#   'NNS',
#   'DT'),
#  ('what you gonna give them all to mommy ?',
#   'give',
#   'give',
#   'what',
#   'them',
#   'WP',
#   'PRP'),
#  ("where're you taking your chair to ?",
#   'take',
#   'taking',
#   'where',
#   'chair',
#   'WRB',
#   'NN'),
#  ("that's right make nice to the machine .",
#   'make',
#   'make',
#   'nice',
#   'machine',
#   'JJ',
#   'NN'),
#  ('is that what dabee sings to you .',
#   'sing',
#   'sings',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ("i'm calling because gail wanted me to say hello to you and she'd like to say hi to her daddy okay .",
#   'say',
#   'say',
#   'hello',
#   'you',
#   'UH',
#   'PRP'),
#  ('you wanna say goodbye to eleanor now ?',
#   'say',
#   'say',
#   'goodbye',
#   'eleanor',
#   'UH',
#   'NNP'),
#  ('who are you going to take for a ride ?',
#   'take',
#   'take',
#   'who',
#   'ride',
#   'WP',
#   'NN'),
#  ('have to make nice to the machine .',
#   'make',
#   'make',
#   'nice',
#   'machine',
#   'JJ',
#   'NN'),
#  ("you know what you didn't say to manuela honey .",
#   'say',
#   'say',
#   'what',
#   'honey',
#   'WP',
#   'NNP'),
#  ("what're you gonna say to yourself ?",
#   'say',
#   'say',
#   'what',
#   'yourself',
#   'WP',
#   'PRP'),
#  ("what're you gonna say to daddy ?",
#   'say',
#   'say',
#   'what',
#   'daddy',
#   'WP',
#   'NN'),
#  ('and who did grandma rosie give to you .',
#   'give',
#   'give',
#   'who',
#   'you',
#   'WP',
#   'PRP'),
#  ('did you give one of those to baby ?',
#   'give',
#   'give',
#   'one',
#   'those',
#   'CD',
#   'DT'),
#  ('give one to baby .', 'give', 'give', 'one', 'baby', 'CD', 'NN'),
#  ('did you feed one of these flowers to baby .',
#   'feed',
#   'feed',
#   'one',
#   'flowers',
#   'CD',
#   'NNS'),
#  ('feed one to baby ?', 'feed', 'feed', 'one', 'baby', 'CD', 'NN'),
#  ("what're you gonna say to grampa ?",
#   'say',
#   'say',
#   'what',
#   'grampa',
#   'WP',
#   'NNP'),
#  ("what're you gonna say to grampa ?",
#   'say',
#   'say',
#   'what',
#   'grampa',
#   'WP',
#   'NNP'),
#  ('what did she say to us the other day ?',
#   'say',
#   'say',
#   'what',
#   'us',
#   'WP',
#   'PRP'),
#  ('and what are we going to bring for tamar for her birthday .',
#   'bring',
#   'bring',
#   'what',
#   'tamar',
#   'WP',
#   'NNP'),
#  ('and what do you say to swiper .',
#   'say',
#   'say',
#   'what',
#   'swiper',
#   'WP',
#   'NNP'),
#  ('who did we sing that to recently ?',
#   'sing',
#   'sing',
#   'who',
#   'that',
#   'WP',
#   'DT'),
#  ("and she sees the picture she'll ask you to take more she wants to send one to each of her friends she wants all those photographs ?",
#   'send',
#   'send',
#   'one',
#   'each',
#   'CD',
#   'DT'),
#  ('what do you say to the recorder ?',
#   'say',
#   'say',
#   'what',
#   'recorder',
#   'WP',
#   'NN'),
#  ("what's the bunny saying to the duck ?",
#   'say',
#   'saying',
#   'what',
#   'duck',
#   'WP',
#   'NN'),
#  ('do you think they are getting ready to take the presents to all of the good little girls and boys ?',
#   'take',
#   'take',
#   'presents',
#   'all',
#   'NNS',
#   'DT'),
#  ("well usually we don't bring things like this to music class because there's so much to do at music class there's hardly any time to do anything else ?",
#   'bring',
#   'bring',
#   'things',
#   'this',
#   'NNS',
#   'DT'),
#  ("here's a birthday card that nonna sent to nina ?",
#   'send',
#   'sent',
#   'that',
#   'nina',
#   'WDT',
#   'NNP'),
#  ('what is the rabbit giving to the deer ?',
#   'give',
#   'giving',
#   'what',
#   'deer',
#   'WP',
#   'NN'),
#  ('what is the rabbit giving to the deer ?',
#   'give',
#   'giving',
#   'what',
#   'deer',
#   'WP',
#   'NN'),
#  ('do you have to call richard at five ?',
#   'call',
#   'call',
#   'richard',
#   'five',
#   'NNP',
#   'CD'),
#  ('oh what are you going say to daddy ?',
#   'say',
#   'say',
#   'what',
#   'daddy',
#   'WP',
#   'NN'),
#  ('look what nonna sent to you ?', 'send', 'sent', 'what', 'you', 'WP', 'PRP'),
#  ('look what nonna sent to nina ?',
#   'send',
#   'sent',
#   'what',
#   'nina',
#   'WP',
#   'NNP'),
#  ("is that what the horsie's saying to the doggie .",
#   'say',
#   'saying',
#   'what',
#   'doggie',
#   'WP',
#   'NN'),
#  ('what are you giving to bunny ?',
#   'give',
#   'giving',
#   'what',
#   'bunny',
#   'WP',
#   'NNP'),
#  ('what are you giving to dolly ?',
#   'give',
#   'giving',
#   'what',
#   'dolly',
#   'WP',
#   'NNP'),
#  ('what do we say to swiper ?', 'say', 'say', 'what', 'swiper', 'WP', 'NNP'),
#  ("it was the biggest audience he'd had in a long time and decided to make the most of it by putting on another show .",
#   'make',
#   'make',
#   'most',
#   'it',
#   'JJS',
#   'PRP'),
#  ('shall we roll it to each other .',
#   'roll',
#   'roll',
#   'it',
#   'other',
#   'PRP',
#   'JJ'),
#  ("no who'd you give the candy to ?",
#   'give',
#   'give',
#   'who',
#   'candy',
#   'WP',
#   'NN'),
#  ('yeah what did he bring to missus block .',
#   'bring',
#   'bring',
#   'what',
#   'block',
#   'WP',
#   'NNP'),
#  ('the cream and what did you say to mommy .',
#   'say',
#   'say',
#   'what',
#   'mommy',
#   'WP',
#   'NN'),
#  ("aren't you gonna say goodbye to the camera ?",
#   'say',
#   'say',
#   'goodbye',
#   'camera',
#   'UH',
#   'NN'),
#  ('would you like to write one on the next page .',
#   'write',
#   'write',
#   'one',
#   'page',
#   'CD',
#   'NN'),
#  ("i'll write it on the when i come to the next page .",
#   'write',
#   'write',
#   'it',
#   'the',
#   'PRP',
#   'DT'),
#  ('did you tell tell manuela what you said to me when it was raining .',
#   'say',
#   'said',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('what do we say blankie to the ?', 'say', 'say', 'what', 'the', 'WP', 'DT'),
#  ("oh well tough luck um so like sometimes she doesn't she'll take a nap from like three to five .",
#   'take',
#   'take',
#   'nap',
#   'three',
#   'NN',
#   'CD'),
#  ('what did she yell to the kittie cat ?',
#   'yell',
#   'yell',
#   'what',
#   'cat',
#   'WP',
#   'NN'),
#  ('can you see how much the they sandy paid for this when she went to the supermarket ?',
#   'pay',
#   'paid',
#   'much',
#   'this',
#   'JJ',
#   'DT'),
#  ('what is he saying to the dinosaur ?',
#   'say',
#   'saying',
#   'what',
#   'dinosaur',
#   'WP',
#   'NN'),
#  ("we'll give the book to to little roo ?",
#   'give',
#   'give',
#   'book',
#   'to',
#   'NN',
#   'IN'),
#  ('can you tell manuela what you said to mommy at the dinner table the other night ?',
#   'say',
#   'said',
#   'what',
#   'mommy',
#   'WP',
#   'NN'),
#  ('and what does dora say to swiper .',
#   'say',
#   'say',
#   'what',
#   'swiper',
#   'WP',
#   'NNP'),
#  ('and what do you say to swiper ?',
#   'say',
#   'say',
#   'what',
#   'swiper',
#   'WP',
#   'NNP'),
#  ('and what do you say to swiper ?',
#   'say',
#   'say',
#   'what',
#   'swiper',
#   'WP',
#   'NNP'),
#  ('what does dora say to swiper ?',
#   'say',
#   'say',
#   'what',
#   'swiper',
#   'WP',
#   'NNP'),
#  ('who will you show it to ?', 'show', 'show', 'who', 'it', 'WP', 'PRP'),
#  ("which i'll have to tell you about so that you know the schedule ?",
#   'tell',
#   'tell',
#   'which',
#   'you',
#   'WDT',
#   'PRP'),
#  ("what do you think he's saying to sky ?",
#   'say',
#   'saying',
#   'what',
#   'sky',
#   'WP',
#   'NNP'),
#  ('what are you going to write for me ?',
#   'write',
#   'write',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ("no that's what nashapoo says to gerry .",
#   'say',
#   'says',
#   'what',
#   'gerry',
#   'WP',
#   'NNP'),
#  ('what does gerry say to nashapoo ?',
#   'say',
#   'say',
#   'what',
#   'nashapoo',
#   'WP',
#   'NNP'),
#  ('can you say goodbye to sharon ?',
#   'say',
#   'say',
#   'goodbye',
#   'sharon',
#   'UH',
#   'NNP'),
#  ('you going to say goodbye to sparky .',
#   'say',
#   'say',
#   'goodbye',
#   'sparky',
#   'UH',
#   'NNP'),
#  ('where did you learn to throw it like that ?',
#   'throw',
#   'throw',
#   'it',
#   'that',
#   'PRP',
#   'DT'),
#  ('and what do we say to joe .', 'say', 'say', 'what', 'joe', 'WP', 'NNP'),
#  ("who's it saying moo to ?", 'say', 'saying', 'who', 'moo', 'WP', 'UH'),
#  ('give what to you ?', 'give', 'give', 'what', 'you', 'WP', 'PRP'),
#  ('lily do you remember how to say open in spanish ?',
#   'say',
#   'say',
#   'open',
#   'spanish',
#   'VB',
#   'NNP'),
#  ('remember what do you say to the door to open the library door .',
#   'say',
#   'say',
#   'what',
#   'door',
#   'WP',
#   'NN'),
#  ('what do you say to swiper ?', 'say', 'say', 'what', 'swiper', 'WP', 'NNP'),
#  ("wanna bring one in to me and i'll roll it out for you .",
#   'bring',
#   'bring',
#   'one',
#   'me',
#   'CD',
#   'PRP'),
#  ('now what what am i going to make with this this is so little .',
#   'make',
#   'make',
#   'what',
#   'what',
#   'WP',
#   'WP'),
#  ("that's the line that you use to pull the choo choo with ?",
#   'pull',
#   'pull',
#   'that',
#   'choo',
#   'WDT',
#   'NN'),
#  ('what did heidi say to you ?', 'say', 'say', 'what', 'you', 'WP', 'PRP'),
#  ('look what ellie gave to us .', 'give', 'gave', 'what', 'us', 'WP', 'PRP'),
#  ('are you saying goodbye to everybody on the train .',
#   'say',
#   'saying',
#   'goodbye',
#   'everybody',
#   'UH',
#   'NN'),
#  ("you like to call the doll gadiga i know we have to tell manuela about this this is lily's new thing .",
#   'tell',
#   'tell',
#   'manuela',
#   'this',
#   'NNP',
#   'DT'),
#  ('what were you saying to the ball when you were calling it gadiga ?',
#   'say',
#   'saying',
#   'what',
#   'ball',
#   'WP',
#   'NN'),
#  ('did you tell manuela what you said to me at the supermarket the other day ?',
#   'say',
#   'said',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('what did you bring to the play ground that you put on the slide ?',
#   'bring',
#   'bring',
#   'what',
#   'ground',
#   'WP',
#   'NN'),
#  ("you'll give it to whom ?", 'give', 'give', 'it', 'whom', 'PRP', 'WP'),
#  ('you have to take of your the socks from your hand ?',
#   'take',
#   'take',
#   'your',
#   'socks',
#   'PRP$',
#   'NNS'),
#  ('look what nonna sent to you ?', 'send', 'sent', 'what', 'you', 'WP', 'PRP'),
#  ('what are we going to read for the night ?',
#   'read',
#   'read',
#   'what',
#   'night',
#   'WP',
#   'NN'),
#  ("but nine i'll give to mommy soon .",
#   'give',
#   'give',
#   'nine',
#   'mommy',
#   'CD',
#   'NN'),
#  ('what do you say to race ?', 'say', 'say', 'what', 'race', 'WP', 'NN'),
#  ('um what does the police man say to corduroy ?',
#   'say',
#   'say',
#   'what',
#   'corduroy',
#   'WP',
#   'NNP'),
#  ('you want to read one to me .', 'read', 'read', 'one', 'me', 'CD', 'PRP'),
#  ('what did you say to me laura ?', 'say', 'say', 'what', 'me', 'WP', 'PRP'),
#  ("what's ernie saying to you ?", 'say', 'saying', 'what', 'you', 'WP', 'PRP'),
#  ('what would the bird big bird bring to the babies ?',
#   'bring',
#   'bring',
#   'what',
#   'babies',
#   'WP',
#   'NNS'),
#  ('well you read one to me .', 'read', 'read', 'one', 'me', 'CD', 'PRP'),
#  ('yeah and what does she say to the little bird you remember ?',
#   'say',
#   'say',
#   'what',
#   'bird',
#   'WP',
#   'NN'),
#  ('do you remember what she said to the little bird ?',
#   'say',
#   'said',
#   'what',
#   'bird',
#   'WP',
#   'NN'),
#  ('and what does she say to the little bird !',
#   'say',
#   'say',
#   'what',
#   'bird',
#   'WP',
#   'NN'),
#  ("who's she saying good night to ?",
#   'say',
#   'saying',
#   'who',
#   'night',
#   'WP',
#   'NN'),
#  ('what is miffy going to make for the birdie ?',
#   'make',
#   'make',
#   'what',
#   'birdie',
#   'WP',
#   'NN'),
#  ('and what did she say to the birdie !',
#   'say',
#   'say',
#   'what',
#   'birdie',
#   'WP',
#   'NN'),
#  ('did you say goodbye to friends at school ?',
#   'say',
#   'say',
#   'goodbye',
#   'friends',
#   'UH',
#   'NNS'),
#  ('you like to sing with clifford what do you like to sing to clifford .',
#   'sing',
#   'sing',
#   'what',
#   'clifford',
#   'WP',
#   'NNP'),
#  ('what are you going to say to the busy bulldozer ?',
#   'say',
#   'say',
#   'what',
#   'bulldozer',
#   'WP',
#   'NN'),
#  ("why're you saying bee bee to the screens nomi .",
#   'say',
#   'saying',
#   'bee',
#   'screens',
#   'FW',
#   'NNS'),
#  ('show linda what nonna sent to you .',
#   'send',
#   'sent',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ("and that's the book that mommy read to nina on the plane ?",
#   'read',
#   'read',
#   'that',
#   'nina',
#   'WDT',
#   'NNP'),
#  ('what do you say to linda ?', 'say', 'say', 'what', 'linda', 'WP', 'NNP'),
#  ('what should we tell daddy what should we say to daddy ?',
#   'say',
#   'say',
#   'what',
#   'daddy',
#   'WP',
#   'NN'),
#  ("who do we ask for help when we don't know which way to go ?",
#   'ask',
#   'ask',
#   'who',
#   'help',
#   'WP',
#   'NN'),
#  ('there he is what do you say to swiper .',
#   'say',
#   'say',
#   'what',
#   'swiper',
#   'WP',
#   'NNP'),
#  ("so some words that i'll say to her that i say kind of funny .",
#   'say',
#   'say',
#   'that',
#   'her',
#   'WDT',
#   'PRP'),
#  ('do you remember say how to say hello in spanish .',
#   'say',
#   'say',
#   'hello',
#   'spanish',
#   'UH',
#   'NNP'),
#  ("what're you writing to nana ?",
#   'write',
#   'writing',
#   'what',
#   'nana',
#   'WP',
#   'NNP'),
#  ('can you tell manuela what did you say to mommy when you were chilly ?',
#   'say',
#   'say',
#   'what',
#   'mommy',
#   'WP',
#   'NN'),
#  ('watch the ball better pay attention to that .',
#   'pay',
#   'pay',
#   'attention',
#   'that',
#   'NN',
#   'DT'),
#  ('and and what do you say to her when she does things that bother you ?',
#   'say',
#   'say',
#   'what',
#   'her',
#   'WP',
#   'PRP'),
#  ('what does she say to you ?', 'say', 'say', 'what', 'you', 'WP', 'PRP'),
#  ('what would the piggy say to erin ?',
#   'say',
#   'say',
#   'what',
#   'erin',
#   'WP',
#   'NNP'),
#  ('what would the pig say to erin ?',
#   'say',
#   'say',
#   'what',
#   'erin',
#   'WP',
#   'NNP'),
#  ("yeah he's getting ready to dance oh and then also what is he saying to jesus .",
#   'say',
#   'saying',
#   'what',
#   'jesus',
#   'WP',
#   'NNP'),
#  ("you're right he said you had to chew chew chew it you said what what did you say to him .",
#   'say',
#   'say',
#   'what',
#   'what',
#   'WP',
#   'WP'),
#  ('what is mavis saying to salty ?',
#   'say',
#   'saying',
#   'what',
#   'salty',
#   'WP',
#   'NNP'),
#  ('what is she saying to salty now ?',
#   'say',
#   'saying',
#   'what',
#   'salty',
#   'WP',
#   'NNP'),
#  ('what would you like to carry in your silly suitcase ?',
#   'carry',
#   'carry',
#   'what',
#   'suitcase',
#   'WP',
#   'NN'),
#  ('what did he decide to do he pushed the hippo to the top and made him fly right into the castle ?',
#   'push',
#   'pushed',
#   'what',
#   'hippo',
#   'WP',
#   'NN'),
#  ('what did the rising tide say to naima ?',
#   'say',
#   'say',
#   'what',
#   'naima',
#   'WP',
#   'NNP'),
#  ('there what do you say to that .', 'say', 'say', 'what', 'that', 'WP', 'DT'),
#  ('they whispered to each other an elephant in rhino city .',
#   'whisper',
#   'whispered',
#   'other',
#   'elephant',
#   'JJ',
#   'NN'),
#  ('whaddo you say to swiper .', 'say', 'say', 'whaddo', 'swiper', 'WP', 'NNP'),
#  ('give one to the snake .', 'give', 'give', 'one', 'snake', 'CD', 'NN'),
#  ('what would the dinosaur say to the big ?',
#   'say',
#   'say',
#   'what',
#   'big',
#   'WP',
#   'JJ'),
#  ('what do you say to that boo .', 'say', 'say', 'what', 'boo', 'WP', 'UH'),
#  ('these are photographs that sam took in the town she went to .',
#   'take',
#   'took',
#   'that',
#   'town',
#   'WDT',
#   'NN'),
#  ("what'd you want ta say to television land ?",
#   'say',
#   'say',
#   'what',
#   'land',
#   'WP',
#   'NN'),
#  ('what did you bring to me ?', 'bring', 'bring', 'what', 'me', 'WP', 'PRP'),
#  ('did you see what nonna sent to you ?',
#   'send',
#   'sent',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ("we'll have to make one for him .",
#   'make',
#   'make',
#   'one',
#   'him',
#   'CD',
#   'PRP'),
#  ('and what is he saying to the lady .',
#   'say',
#   'saying',
#   'what',
#   'lady',
#   'WP',
#   'NN'),
#  ('who are you going to feed with the fork ?',
#   'feed',
#   'feed',
#   'who',
#   'fork',
#   'WP',
#   'NN'),
#  ('what are you going to feed to him ?',
#   'feed',
#   'feed',
#   'what',
#   'him',
#   'WP',
#   'PRP'),
#  ('now what did the mommy always say to the baby horse .',
#   'say',
#   'say',
#   'what',
#   'horse',
#   'WP',
#   'NN'),
#  ('what did the mommy say to the baby horse every time ?',
#   'say',
#   'say',
#   'what',
#   'horse',
#   'WP',
#   'NN'),
#  ('what are you going to make with them ?',
#   'make',
#   'make',
#   'what',
#   'them',
#   'WP',
#   'PRP'),
#  ('who are you giving the peas to ?',
#   'give',
#   'giving',
#   'who',
#   'peas',
#   'WP',
#   'NNS'),
#  ('what are you going to make for me ?',
#   'make',
#   'make',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('who are we going to fly in the airplane to see ?',
#   'fly',
#   'fly',
#   'who',
#   'airplane',
#   'WP',
#   'NN'),
#  ("what's she bringing to the baby ?",
#   'bring',
#   'bringing',
#   'what',
#   'baby',
#   'WP',
#   'NN'),
#  ('would you like me to take you in a ?',
#   'take',
#   'take',
#   'you',
#   'a',
#   'PRP',
#   'DT'),
#  ('what do you say to mom ?', 'say', 'say', 'what', 'mom', 'WP', 'NN'),
#  ('do you want to give one to cromer ?',
#   'give',
#   'give',
#   'one',
#   'cromer',
#   'CD',
#   'NNP'),
#  ('what did you say to marian on the telephone ?',
#   'say',
#   'say',
#   'what',
#   'marian',
#   'WP',
#   'NNP'),
#  ('oh what do you usually say to snow .',
#   'say',
#   'say',
#   'what',
#   'snow',
#   'WP',
#   'NN'),
#  ('can i read one to you .', 'read', 'read', 'one', 'you', 'CD', 'PRP'),
#  ('and what do i say to cinderella ?',
#   'say',
#   'say',
#   'what',
#   'cinderella',
#   'WP',
#   'NNP'),
#  ("and what'd you say to grandma .",
#   'say',
#   'say',
#   'what',
#   'grandma',
#   'WP',
#   'NN'),
#  ("what'd you say to him ?", 'say', 'say', 'what', 'him', 'WP', 'PRP'),
#  ('emily what do they pass around to each other .',
#   'pass',
#   'pass',
#   'what',
#   'other',
#   'WP',
#   'JJ'),
#  ('you know what he said to me this morning when i came in ?',
#   'say',
#   'said',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('so he decided to make the hill into a .',
#   'make',
#   'make',
#   'hill',
#   'a',
#   'NN',
#   'DT'),
#  ('i want you to tell me your about your experience this weekend with your cousins .',
#   'tell',
#   'tell',
#   'your',
#   'experience',
#   'PRP$',
#   'NN'),
#  ("yeah who're they gonna bring the flowers to .",
#   'bring',
#   'bring',
#   'who',
#   'flowers',
#   'WP',
#   'NNS'),
#  ('oh that story is all about how the mother bear tells a story to each of her little bear children .',
#   'tell',
#   'tells',
#   'story',
#   'each',
#   'NN',
#   'DT'),
#  ('want me to pull your ears like this ?',
#   'pull',
#   'pull',
#   'ears',
#   'this',
#   'NNS',
#   'DT'),
#  ('well she came in about seven and the reaction was over by eleven thirty i sent her home with the benedryl with the instructions to her husband .',
#   'send',
#   'sent',
#   'thirty',
#   'her',
#   'CD',
#   'PRP'),
#  ("i don't think they can say hello to you .",
#   'say',
#   'say',
#   'hello',
#   'you',
#   'UH',
#   'PRP'),
#  ('well i know who did you give it to .',
#   'give',
#   'give',
#   'who',
#   'it',
#   'WP',
#   'PRP'),
#  ('you know what do you think you might want to show erin from this .',
#   'show',
#   'show',
#   'erin',
#   'this',
#   'NNP',
#   'DT'),
#  ('but when i get some after i finish putting away the dishes then i will write down what you would like me to say to him .',
#   'say',
#   'say',
#   'what',
#   'him',
#   'WP',
#   'PRP'),
#  ('what to bring for snack ?', 'bring', 'bring', 'what', 'snack', 'WP', 'NN'),
#  ('and what did nance say to you .', 'say', 'say', 'what', 'you', 'WP', 'PRP'),
#  ('how much do i have to pay you for all these things ?',
#   'pay',
#   'pay',
#   'much',
#   'you',
#   'JJ',
#   'PRP'),
#  ("shall we read one of these riddles these riddles to you and see if you think it's funny .",
#   'read',
#   'read',
#   'one',
#   'riddles',
#   'CD',
#   'NNS'),
#  ('what did the big firecracker say to the little firecracker ?',
#   'say',
#   'say',
#   'what',
#   'firecracker',
#   'WP',
#   'NN'),
#  ("what's a big firecracker say to a little firecracker ?",
#   'say',
#   'say',
#   'what',
#   'firecracker',
#   'WP',
#   'NN'),
#  ('and every once in a while peter the horse would come along and say hello to her ?',
#   'say',
#   'say',
#   'hello',
#   'her',
#   'UH',
#   'PRP'),
#  ('do you want to tell erin about the um about the scooby doo shows ?',
#   'tell',
#   'tell',
#   'erin',
#   'the',
#   'NNP',
#   'DT'),
#  ('what did he say to you ?', 'say', 'say', 'what', 'you', 'WP', 'PRP'),
#  ('what do you say to lise .', 'say', 'say', 'what', 'lise', 'WP', 'NNP'),
#  ('where do we take this tractor to ?',
#   'take',
#   'take',
#   'where',
#   'tractor',
#   'WRB',
#   'NN'),
#  ('what did maria say that day to tamar at the play ground ?',
#   'say',
#   'say',
#   'what',
#   'tamar',
#   'WP',
#   'NNP'),
#  ('we can give one to each child in the school .',
#   'give',
#   'give',
#   'one',
#   'child',
#   'CD',
#   'NN'),
#  ('now i thought we were not going to take that and move with it now who should we give that to .',
#   'give',
#   'give',
#   'who',
#   'that',
#   'WP',
#   'DT'),
#  ("want me to get your little packet of kleenex that you take to shirley's ?",
#   'take',
#   'take',
#   'that',
#   'shirley',
#   'WDT',
#   'NNP'),
#  ('oh who are you going to feed them to .',
#   'feed',
#   'feed',
#   'who',
#   'them',
#   'WP',
#   'PRP'),
#  ("what'd your mom say to you ?", 'say', 'say', 'what', 'you', 'WP', 'PRP'),
#  ('what does pushba need to say to veena ?',
#   'say',
#   'say',
#   'what',
#   'veena',
#   'WP',
#   'NNP'),
#  ('the policemen are coming out to say hello to the mother duck .',
#   'say',
#   'say',
#   'hello',
#   'duck',
#   'UH',
#   'NN'),
#  ('do you want to write a number adam with this ?',
#   'write',
#   'write',
#   'number',
#   'this',
#   'NN',
#   'DT'),
#  ('and for saying goodbye to old friends .',
#   'say',
#   'saying',
#   'goodbye',
#   'friends',
#   'UH',
#   'NNS'),
#  ('did they teach you to do that at preschool .',
#   'teach',
#   'teach',
#   'you',
#   'that',
#   'PRP',
#   'DT'),
#  ('what are you going to make with your circles ?',
#   'make',
#   'make',
#   'what',
#   'circles',
#   'WP',
#   'NNS'),
#  ('who are you going to take into the train ?',
#   'take',
#   'take',
#   'who',
#   'train',
#   'WP',
#   'NN'),
#  ('what else you take down to the beach with you ?',
#   'take',
#   'take',
#   'what',
#   'beach',
#   'WP',
#   'NN'),
#  ('and we took him to um which .',
#   'take',
#   'took',
#   'him',
#   'which',
#   'PRP',
#   'WDT'),
#  ("what she was saying to me was hm having kids having more than one more than two even is okay if you're if you're the rich and privileged class essentially ?",
#   'say',
#   'saying',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('what did maggie bring to you ?',
#   'bring',
#   'bring',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ("now let's see everybody that they brought to you .",
#   'bring',
#   'brought',
#   'that',
#   'you',
#   'WDT',
#   'PRP'),
#  ('who did you give cup cakes to ?',
#   'give',
#   'give',
#   'who',
#   'cakes',
#   'WP',
#   'NNS'),
#  ('what did maryse give to you ?', 'give', 'give', 'what', 'you', 'WP', 'PRP'),
#  ("played back to us and then she'd take it to a ?",
#   'take',
#   'take',
#   'it',
#   'a',
#   'PRP',
#   'DT'),
#  ('where you going to take him to ?',
#   'take',
#   'take',
#   'where',
#   'him',
#   'WRB',
#   'PRP'),
#  ('do you remember what the story was about that i read to miriam and brian ?',
#   'read',
#   'read',
#   'that',
#   'miriam',
#   'WDT',
#   'NNP'),
#  ("it's what evan gave to you right ?",
#   'give',
#   'gave',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ('what is he saying to her ?', 'say', 'saying', 'what', 'her', 'WP', 'PRP'),
#  ('the one that nonna sent to you .',
#   'send',
#   'sent',
#   'that',
#   'you',
#   'WDT',
#   'PRP'),
#  ('what would you like to carry in your bag ?',
#   'carry',
#   'carry',
#   'what',
#   'bag',
#   'WP',
#   'NN'),
#  ('oh yes i wanted to ask you about those but i was too tired last night ?',
#   'ask',
#   'ask',
#   'you',
#   'those',
#   'PRP',
#   'DT'),
#  ("it's what you say to me .", 'say', 'say', 'what', 'me', 'WP', 'PRP'),
#  ("i'll uh wipe this out before i give to to my transcriber ?",
#   'give',
#   'give',
#   'to',
#   'transcriber',
#   'IN',
#   'NN'),
#  ("however there's a story that we'd like you to read to guy ?",
#   'read',
#   'read',
#   'that',
#   'guy',
#   'WDT',
#   'NN'),
#  ('in in box number one is a story book which i can read to you ?',
#   'read',
#   'read',
#   'which',
#   'you',
#   'WDT',
#   'PRP'),
#  ('we were we were going to rent him out for awhile ?',
#   'rent',
#   'rent',
#   'him',
#   'awhile',
#   'PRP',
#   'RB'),
#  ('give it to whom ?', 'give', 'give', 'it', 'whom', 'PRP', 'WP'),
#  ('what should we say to them ?', 'say', 'say', 'what', 'them', 'WP', 'PRP'),
#  ("and what's the lady saying to the policeman ?",
#   'say',
#   'saying',
#   'what',
#   'policeman',
#   'WP',
#   'NN'),
#  ('who are you going to bring to school nina ?',
#   'bring',
#   'bring',
#   'who',
#   'school',
#   'WP',
#   'NN'),
#  ('did you see this picture that olympia sent to us in the mail ?',
#   'send',
#   'sent',
#   'that',
#   'us',
#   'WDT',
#   'PRP'),
#  ('and our mother came in and she said to us two .',
#   'say',
#   'said',
#   'us',
#   'two',
#   'PRP',
#   'CD'),
#  ('show the doggie what santa claus brought to you .',
#   'bring',
#   'brought',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ("maybe he'd like to meet the fish that bob brought to you .",
#   'bring',
#   'brought',
#   'that',
#   'you',
#   'WDT',
#   'PRP'),
#  ('look nonna did you see what bob brought to nina .',
#   'bring',
#   'brought',
#   'what',
#   'nina',
#   'WP',
#   'NNP'),
#  ("that's who i took to the aquarium .",
#   'take',
#   'took',
#   'who',
#   'aquarium',
#   'WP',
#   'NN'),
#  ("is that what they're going to ask santa claus for christmas .",
#   'ask',
#   'ask',
#   'what',
#   'claus',
#   'WP',
#   'NNP'),
#  ("don't you want to say hello to courtney you haven't seen courtney in two weeks ?",
#   'say',
#   'say',
#   'hello',
#   'courtney',
#   'UH',
#   'NNP'),
#  ("that's what i say to that .", 'say', 'say', 'what', 'that', 'WP', 'DT'),
#  ('who did santa claus bring the vacuum cleaner to ?',
#   'bring',
#   'bring',
#   'who',
#   'cleaner',
#   'WP',
#   'NN'),
#  ('who did santa claus give the vacuum cleaner to ?',
#   'give',
#   'give',
#   'who',
#   'cleaner',
#   'WP',
#   'NN'),
#  ('would you like us to read one of the books to you ?',
#   'read',
#   'read',
#   'one',
#   'books',
#   'CD',
#   'NNS'),
#  ('what is he saying to you ?', 'say', 'saying', 'what', 'you', 'WP', 'PRP'),
#  ('what is what is she saying to the baby ?',
#   'say',
#   'saying',
#   'what',
#   'baby',
#   'WP',
#   'NN'),
#  ('what is she saying to her mother ?',
#   'say',
#   'saying',
#   'what',
#   'mother',
#   'WP',
#   'NN'),
#  ("what's the mother saying to the daddy ?",
#   'say',
#   'saying',
#   'what',
#   'daddy',
#   'WP',
#   'NN'),
#  ("i've got this storybook that they gave to you ?",
#   'give',
#   'gave',
#   'that',
#   'you',
#   'WDT',
#   'PRP'),
#  ('what do you say to lise ?', 'say', 'say', 'what', 'lise', 'WP', 'NNP'),
#  ("what do you think he's saying to the lady ?",
#   'say',
#   'saying',
#   'what',
#   'lady',
#   'WP',
#   'NN'),
#  ('what do you think he says to her ?',
#   'say',
#   'says',
#   'what',
#   'her',
#   'WP',
#   'PRP'),
#  ('who shall we bring to the beach ?',
#   'bring',
#   'bring',
#   'who',
#   'beach',
#   'WP',
#   'NN'),
#  ('and what did she say to you ?', 'say', 'say', 'what', 'you', 'WP', 'PRP'),
#  ('what did nonna say to you on the telephone this morning ?',
#   'say',
#   'say',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ("you'll have to pay ursula for that .",
#   'pay',
#   'pay',
#   'ursula',
#   'that',
#   'NNP',
#   'DT'),
#  ('well she started to take that cover from the ?',
#   'take',
#   'take',
#   'cover',
#   'the',
#   'NN',
#   'DT'),
#  ('oh is that a story that they read to you .',
#   'read',
#   'read',
#   'that',
#   'you',
#   'WDT',
#   'PRP'),
#  ('is that a story that somebody read to you at school .',
#   'read',
#   'read',
#   'that',
#   'you',
#   'WDT',
#   'PRP'),
#  ("what's this little girl saying to him do you think ?",
#   'say',
#   'saying',
#   'what',
#   'him',
#   'WP',
#   'PRP'),
#  ('is that what you would say to the lion .',
#   'say',
#   'say',
#   'what',
#   'lion',
#   'WP',
#   'NN'),
#  ('what did you want to say about it ross ?',
#   'say',
#   'say',
#   'what',
#   'it',
#   'WP',
#   'PRP'),
#  ('what do you want to say to the tape recorder ross ?',
#   'say',
#   'say',
#   'what',
#   'recorder',
#   'WP',
#   'NN'),
#  ('mailing a letter to whom ?',
#   'mail',
#   'mailing',
#   'letter',
#   'whom',
#   'NN',
#   'WP'),
#  ('what are you going to make for me ?',
#   'make',
#   'make',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ("okay i have this exciting book here that i'd like to read to you .",
#   'read',
#   'read',
#   'that',
#   'you',
#   'WDT',
#   'PRP'),
#  ('did your daddy read a book like this to you ?',
#   'read',
#   'read',
#   'book',
#   'this',
#   'NN',
#   'DT'),
#  ("what's the mommy say to these kids on the ground ?",
#   'say',
#   'say',
#   'what',
#   'kids',
#   'WP',
#   'NNS'),
#  ("what's she say to them ?", 'say', 'say', 'what', 'them', 'WP', 'PRP'),
#  ('you have to give some to one of your dollies .',
#   'give',
#   'give',
#   'some',
#   'one',
#   'DT',
#   'CD'),
#  ('well what else do we need to bring to the beach ?',
#   'bring',
#   'bring',
#   'what',
#   'beach',
#   'WP',
#   'NN'),
#  ("like when she makes up her own songs that you can't understand she'll sing it to the tune of that .",
#   'sing',
#   'sing',
#   'songs',
#   'that',
#   'NNS',
#   'WDT'),
#  ("why don't you show some more to jessica right now and we'll hang them up you know .",
#   'show',
#   'show',
#   'more',
#   'jessica',
#   'JJR',
#   'NNP'),
#  ('oh what do you want to make spaghetti in .',
#   'make',
#   'make',
#   'what',
#   'spaghetti',
#   'WP',
#   'NN'),
#  ('what she say to the cricket ?',
#   'say',
#   'say',
#   'what',
#   'cricket',
#   'WP',
#   'NN'),
#  ('you ask ursula to tell you about this ?',
#   'tell',
#   'tell',
#   'you',
#   'this',
#   'PRP',
#   'DT'),
#  ('what else did millisandy say to you ?',
#   'say',
#   'say',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ('is that what she says to the tiger ?',
#   'say',
#   'says',
#   'what',
#   'tiger',
#   'WP',
#   'NN'),
#  ('what are they saying to each other ?',
#   'say',
#   'saying',
#   'what',
#   'other',
#   'WP',
#   'JJ'),
#  ("who's he giving the milk to ?",
#   'give',
#   'giving',
#   'who',
#   'milk',
#   'WP',
#   'NN'),
#  ('what did you say to mommy ?', 'say', 'say', 'what', 'mommy', 'WP', 'NN'),
#  ('when did you learn to throw the ball like that ?',
#   'throw',
#   'throw',
#   'ball',
#   'that',
#   'NN',
#   'DT'),
#  ('is that what you say to a nursie .',
#   'say',
#   'say',
#   'what',
#   'nursie',
#   'WP',
#   'NN'),
#  ('what did the mommy say to the little girl ?',
#   'say',
#   'say',
#   'what',
#   'girl',
#   'WP',
#   'NN'),
#  ('take them to the ?', 'take', 'take', 'them', 'the', 'PRP', 'DT'),
#  ("what's that mommy saying to all these kids ?",
#   'say',
#   'saying',
#   'what',
#   'kids',
#   'WP',
#   'NNS'),
#  ('what does she say to her little girl ?',
#   'say',
#   'say',
#   'what',
#   'girl',
#   'WP',
#   'NN'),
#  ("what's the mom say to the little girl ?",
#   'say',
#   'say',
#   'what',
#   'girl',
#   'WP',
#   'NN'),
#  ('what do you say to mommy when she does it right ?',
#   'say',
#   'say',
#   'what',
#   'mommy',
#   'WP',
#   'NN'),
#  ('she gave some to each of them .',
#   'give',
#   'gave',
#   'some',
#   'each',
#   'DT',
#   'DT'),
#  ('what do you want to find in it ?',
#   'find',
#   'find',
#   'what',
#   'it',
#   'WP',
#   'PRP'),
#  ("what's her mommy say to her ?", 'say', 'say', 'what', 'her', 'WP', 'PRP'),
#  ("what does mommy say to the little children when they're on the merry go round ?",
#   'say',
#   'say',
#   'what',
#   'children',
#   'WP',
#   'NNS'),
#  ("what's he saying to you ?", 'say', 'saying', 'what', 'you', 'WP', 'PRP'),
#  ('what are you going to ask santa for sarah ?',
#   'ask',
#   'ask',
#   'what',
#   'santa',
#   'WP',
#   'NNP'),
#  ('i have ta give two to auntie .',
#   'give',
#   'give',
#   'two',
#   'auntie',
#   'CD',
#   'NN'),
#  ('what is she gonna say to you ?', 'say', 'say', 'what', 'you', 'WP', 'PRP'),
#  ('what is she gonna say to you ?', 'say', 'say', 'what', 'you', 'WP', 'PRP'),
#  ("what's this little boy gonna say to the car ?",
#   'say',
#   'say',
#   'what',
#   'car',
#   'WP',
#   'NN'),
#  ("what's the mommy going to say to all these kids ?",
#   'say',
#   'say',
#   'what',
#   'kids',
#   'WP',
#   'NNS'),
#  ('right do you remember what you said to that boy who carried our bag out ?',
#   'say',
#   'said',
#   'what',
#   'boy',
#   'WP',
#   'NN'),
#  ('what did the dentist say to you ?',
#   'say',
#   'say',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ("do you want to see what you're going to give daddy for christmas .",
#   'give',
#   'give',
#   'what',
#   'daddy',
#   'WP',
#   'NNP'),
#  ('what does the daddy say to all the children ?',
#   'say',
#   'say',
#   'what',
#   'children',
#   'WP',
#   'NNS'),
#  ('what does he say to everyone ?',
#   'say',
#   'say',
#   'what',
#   'everyone',
#   'WP',
#   'NN'),
#  ('what else do we say to jonathan ?',
#   'say',
#   'say',
#   'what',
#   'jonathan',
#   'WP',
#   'NNP'),
#  ('what do you say to chrissy and eddie when you see them ?',
#   'say',
#   'say',
#   'what',
#   'chrissy',
#   'WP',
#   'NNP'),
#  ('what do you say to them ?', 'say', 'say', 'what', 'them', 'WP', 'PRP'),
#  ('but what if i get another one and you can have one and then i can also send one to grandma ?',
#   'send',
#   'send',
#   'one',
#   'grandma',
#   'CD',
#   'NN'),
#  ('what do you say to your children when they go on the ride ?',
#   'say',
#   'say',
#   'what',
#   'children',
#   'WP',
#   'NNS'),
#  ('what does he say to his mommy ?',
#   'say',
#   'say',
#   'what',
#   'mommy',
#   'WP',
#   'NN'),
#  ("what's the mommy say to the kids on the merry go round when they ride crazy like that ?",
#   'say',
#   'say',
#   'what',
#   'kids',
#   'WP',
#   'NNS'),
#  ('and the great pumpkin gave all of that to us .',
#   'give',
#   'gave',
#   'all',
#   'that',
#   'DT',
#   'DT'),
#  ('do you know how to say hello in french ?',
#   'say',
#   'say',
#   'hello',
#   'french',
#   'UH',
#   'NNP'),
#  ('what does he say to his mom ?', 'say', 'say', 'what', 'mom', 'WP', 'NN'),
#  ('who was she trying to call at the north pole ?',
#   'call',
#   'call',
#   'who',
#   'pole',
#   'WP',
#   'NN'),
#  ('can i say hello to her .', 'say', 'say', 'hello', 'her', 'UH', 'PRP'),
#  ('generous people give two to to another boy .',
#   'give',
#   'give',
#   'two',
#   'boy',
#   'CD',
#   'NN'),
#  ('you know what the man said to me .',
#   'say',
#   'said',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('what does the mommy say to the little girl ?',
#   'say',
#   'say',
#   'what',
#   'girl',
#   'WP',
#   'NN'),
#  ('what does johnny say to christopher ?',
#   'say',
#   'say',
#   'what',
#   'christopher',
#   'WP',
#   'NNP'),
#  ('and what do they try to hit the puck into ?',
#   'hit',
#   'hit',
#   'what',
#   'puck',
#   'WP',
#   'NN'),
#  ('what are you going to give me for my birthday ?',
#   'give',
#   'give',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ("we'll go to the lyon's and then when we leave the lyon's we'll take what's left and take it to the connor's .",
#   'take',
#   'take',
#   'it',
#   'connor',
#   'PRP',
#   'NNPS'),
#  ('okay but what do i say in english to them ?',
#   'say',
#   'say',
#   'what',
#   'english',
#   'WP',
#   'NNP'),
#  ('so how much does he have to pay for it ?',
#   'pay',
#   'pay',
#   'much',
#   'it',
#   'JJ',
#   'PRP'),
#  ('they took each other to the barn ?',
#   'take',
#   'took',
#   'other',
#   'barn',
#   'JJ',
#   'NN'),
#  ('so what would they say to each other ?',
#   'say',
#   'say',
#   'what',
#   'other',
#   'WP',
#   'JJ'),
#  ('what would you have said to me and mom ?',
#   'say',
#   'said',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('did you tell daddy what you want andy to give you for your birthday ?',
#   'give',
#   'give',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ('so i was trying to think of what to make for dinner that they would like .',
#   'make',
#   'make',
#   'what',
#   'dinner',
#   'WP',
#   'NN'),
#  ("yeah big stores you don't say hello but small stores you might say hello to the store owner .",
#   'say',
#   'say',
#   'hello',
#   'owner',
#   'UH',
#   'NN'),
#  ('what would you say to my fellow workers ?',
#   'say',
#   'say',
#   'what',
#   'workers',
#   'WP',
#   'NNS'),
#  ('gives a whole new meaning to bipolar .',
#   'give',
#   'gives',
#   'meaning',
#   'bipolar',
#   'NN',
#   'JJ'),
#  ("i suppose it's easier to take care of five of them if you're sleeping with them .",
#   'take',
#   'take',
#   'care',
#   'five',
#   'NN',
#   'CD'),
#  ("i don't think you're really supposed to push the money like that ?",
#   'push',
#   'push',
#   'money',
#   'that',
#   'NN',
#   'DT'),
#  ('and what did the king say to them ?',
#   'say',
#   'say',
#   'what',
#   'them',
#   'WP',
#   'PRP'),
#  ("what's she bringing to them ?",
#   'bring',
#   'bringing',
#   'what',
#   'them',
#   'WP',
#   'PRP'),
#  ('okay so what did they say to the cat .',
#   'say',
#   'say',
#   'what',
#   'cat',
#   'WP',
#   'NN'),
#  ("wanda doesn't know what to make of all these people walking in and out .",
#   'make',
#   'make',
#   'what',
#   'people',
#   'WP',
#   'NNS'),
#  ('can you give one to karen ?', 'give', 'give', 'one', 'karen', 'CD', 'NNP'),
#  ("we didn't even have to bring the car to the to the gas station .",
#   'bring',
#   'bring',
#   'car',
#   'the',
#   'NN',
#   'DT'),
#  ('so what do what do you think the little girl is saying to the policeman ?',
#   'say',
#   'saying',
#   'what',
#   'policeman',
#   'WP',
#   'NN'),
#  ("paul doesn't know what to think about you .",
#   'think',
#   'think',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ("what's doctor weist going to say about that when he hears that ?",
#   'say',
#   'say',
#   'what',
#   'that',
#   'WP',
#   'DT'),
#  ("and i'm going to get you a special notebook that you can learn how to write music with .",
#   'write',
#   'write',
#   'that',
#   'music',
#   'WDT',
#   'NN'),
#  ("that's what the worms say to each other ?",
#   'say',
#   'say',
#   'what',
#   'other',
#   'WP',
#   'JJ'),
#  ('now what is the little girl going to take to camp for a toy ?',
#   'take',
#   'take',
#   'what',
#   'camp',
#   'WP',
#   'NN'),
#  ('did you hear the three things that sandy said to us ?',
#   'say',
#   'said',
#   'that',
#   'us',
#   'WDT',
#   'PRP'),
#  ('roman what do you like to make with those things .',
#   'make',
#   'make',
#   'what',
#   'things',
#   'WP',
#   'NNS'),
#  ("what'd she say to that ?", 'say', 'say', 'what', 'that', 'WP', 'DT'),
#  ("okay so maybe you don't have to tell us again how about this ?",
#   'tell',
#   'tell',
#   'us',
#   'this',
#   'PRP',
#   'DT'),
#  ("i read something today for one of my classes that says that children don't really talk to each other .",
#   'read',
#   'read',
#   'something',
#   'one',
#   'NN',
#   'CD'),
#  ('what were you going to say about your daddy ?',
#   'say',
#   'say',
#   'what',
#   'daddy',
#   'WP',
#   'NN'),
#  ('well what do want to say into it .',
#   'say',
#   'say',
#   'what',
#   'it',
#   'WP',
#   'PRP'),
#  ('did i tell you what she said to me this morning ?',
#   'say',
#   'said',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('did i tell you what she said to me this morning ?',
#   'say',
#   'said',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ("what do you think she's whispering to you ?",
#   'whisper',
#   'whispering',
#   'what',
#   'you',
#   'WP',
#   'PRP'),
#  ('but remember right before we went to the first mall you were not feeling well remember what you said to me ?',
#   'say',
#   'said',
#   'what',
#   'me',
#   'WP',
#   'PRP'),
#  ('what are the cat and dog saying to each other ?',
#   'say',
#   'saying',
#   'what',
#   'other',
#   'WP',
#   'JJ'),
#  ("because you know why i didn't want you to drop them like that ?",
#   'drop',
#   'drop',
#   'them',
#   'that',
#   'PRP',
#   'DT'),
#  ("i'll have to make a big tunnel for this .",
#   'make',
#   'make',
#   'tunnel',
#   'this',
#   'NN',
#   'DT'),
#  ('um well you know you were telling me yesterday about some of the things with the magic show maybe helga would like to hear about the magic show you set up ?',
#   'tell',
#   'telling',
#   'me',
#   'some',
#   'PRP',
#   'DT'),
#  ('do you want to ask your mother for that ?',
#   'ask',
#   'ask',
#   'mother',
#   'that',
#   'NN',
#   'DT'),
#  ('you have to take care of what ?',
#   'take',
#   'take',
#   'care',
#   'what',
#   'NN',
#   'WP'),
#  ('giving one to melissa ?', 'give', 'giving', 'one', 'melissa', 'CD', 'NNP'),
#  ('what did you want to say about a story ?',
#   'say',
#   'say',
#   'what',
#   'story',
#   'WP',
#   'NN'),
#  ('what do you say to gail ?', 'say', 'say', 'what', 'gail', 'WP', 'NNP'),
#  ('okay okay oh wait did you want to tell helga about your .',
#   'tell',
#   'tell',
#   'helga',
#   'your',
#   'NNP',
#   'PRP$'),
#  ('and what did you say to that ross ?',
#   'say',
#   'say',
#   'what',
#   'ross',
#   'WP',
#   'NNP'),
#  ('hey daddy tell them about this and tell them that i gave it to you too .',
#   'tell',
#   'tell',
#   'them',
#   'this',
#   'PRP',
#   'DT'),
#  ('can you hand one to daddad ?',
#   'hand',
#   'hand',
#   'one',
#   'daddad',
#   'CD',
#   'NNP')]

# %%
dos_sents, dos_lemmas, dos_verbs, _, _ = list(zip(*DOS_FILTERED))
len(Counter(dos_lemmas))
# Out:
# 48

# %%
pps_sents, pps_lemmas, pps_verbs, _, _ = list(zip(*PPS_FILTERED))
len(Counter(pps_lemmas))
# Out:
# 69

# %%
alternating = set(dos_lemmas).intersection(set(pps_lemmas))
do_only = set(dos_lemmas) - set(pps_lemmas)
pp_only = set(pps_lemmas) - set(dos_lemmas)

len(alternating), len(do_only), len(pp_only)
# Out:
# (38, 10, 31)

# %%
# with open(f"{args.outpath}/postags.txt", 'w') as f:
postags = []
for batch in get_batch(corpus, batch_size=256):
    tags = get_postags(batch, 256, nlp)

    for j, item in enumerate(tags):
        # print(j, item)
        if item == []:
            postags.append("")
        else:
            tokens, pos_tags = list(zip(*item))
            pos_string = " ".join(pos_tags)
            postags.append(pos_string)

# %%
for sentence in do_examples:
    doc = nlp(sentence)
    for entity in doc:
        if entity.pos_ == "VERB":
            # print(entity.text, [(c, c.dep_, c.head) for c in entity.children])
            # for child in entity.children:
            #     if child.dep_ == "dative" and child.pos_ in ["NOUN", "PRON", "PROPN"]\
            #     or child.dep_ == "dobj" and child.pos_ in ["NOUN", "PRON", "PROPN"]:
            #         print(entity.text, child.text, child.pos_)

            # print("")
            children = get_children_flatten(entity, dep=True, return_tokens=True)
            print(children)
    print("")
# Out:
# [('she', 'nsubj', 'PRP', 0, 0, she), ('me', 'dative', 'PRP', 0, 2, me), ('ball', 'dobj', 'NN', 0, 4, ball), ('the', 'det', 'DT', 1, 3, the), ('.', 'punct', '.', 0, 5, .)]
#
# [('she', 'nsubj', 'PRP', 0, 0, she), ('mom', 'dative', 'NN', 0, 2, mom), ('ball', 'dobj', 'NN', 0, 4, ball), ('the', 'det', 'DT', 1, 3, the), ('.', 'punct', '.', 0, 5, .)]
#
# [('she', 'nsubj', 'PRP', 0, 0, she), ('grandma', 'dative', 'NN', 0, 2, grandma), ('book', 'dobj', 'NN', 0, 5, book), ('the', 'det', 'DT', 1, 3, the), ('big', 'amod', 'JJ', 1, 4, big), ('.', 'punct', '.', 0, 6, .)]
#
# [('she', 'nsubj', 'PRP', 0, 0, she), ('is', 'aux', 'VBZ', 0, 1, is), ('dog', 'dative', 'NN', 0, 4, dog), ('the', 'det', 'DT', 1, 3, the), ('ball', 'dobj', 'NN', 0, 7, ball), ('the', 'det', 'DT', 1, 5, the), ('big', 'amod', 'JJ', 1, 6, big), ('.', 'punct', '.', 0, 8, .)]
#
# [('she', 'nsubj', 'PRP', 0, 0, she), ('had', 'aux', 'VBD', 0, 1, had), ('me', 'dative', 'PRP', 0, 3, me), ('ball', 'dobj', 'NN', 0, 5, ball), ('the', 'det', 'DT', 1, 4, the), ('.', 'punct', '.', 0, 6, .)]
#
# [('she', 'nsubj', 'PRP', 0, 0, she), ('has', 'aux', 'VBZ', 0, 1, has), ('mommy', 'dative', 'NN', 0, 3, mommy), ('ball', 'dobj', 'NN', 0, 5, ball), ('the', 'det', 'DT', 1, 4, the)]

# %%
dos = []
pps = []

for sentence in do_examples + pp_examples:
    doc = nlp(sentence)
    do = False
    pp = False
    for entity in doc:
        if entity.pos_ == "VERB":
            # print(entity.text, [(c, c.dep_, c.head) for c in entity.children])
            # for child in entity.children:
            #     if (child.dep_ == "dative" or child.dep_ == "prep") and child.text_ == "to":
            #         pobj = ""
            #         for grandchild in child.children:
            #             if grandchild.dep_ == "pobj":
            #                 pobj = grandchild.text_                            
            #         print(entity.text, child.text, child.pos_)

            children = get_children_flatten(entity, 0, dep=True)
            # print(children)
            tokens, dep, pos_string, depth, index = list(zip(*children))
            if "to" in tokens:
                if ("dative" in dep and "pobj" in dep) or ("prep" in dep and "pobj" in dep):
                    pp = True
                    # pps.append(sentence)
                    break
                # possibility for PP
            else:
                # possibility for DO
                # concatenation of dep and depth
                dep_depth = [f"{d}_{str(depth[i])}" for i, d in enumerate(dep)]
                if ("dobj_0" in dep_depth and "dative_0" in dep_depth) or Counter(dep_depth)['dobj_0'] >= 2:
                    do = True
                    # dos.append(sentence)
                    break
    if do:
        dos.append(sentence)
    elif pp:
        pps.append(sentence)
            # for child in children:
# Out:
# [('she', 'nsubj', 'PRP', 0, 0), ('me', 'dative', 'PRP', 0, 2), ('ball', 'dobj', 'NN', 0, 4), ('the', 'det', 'DT', 1, 3), ('.', 'punct', '.', 0, 5)]
# [('she', 'nsubj', 'PRP', 0, 0), ('mom', 'dative', 'NN', 0, 2), ('ball', 'dobj', 'NN', 0, 4), ('the', 'det', 'DT', 1, 3), ('.', 'punct', '.', 0, 5)]
# [('she', 'nsubj', 'PRP', 0, 0), ('grandma', 'dative', 'NN', 0, 2), ('book', 'dobj', 'NN', 0, 5), ('the', 'det', 'DT', 1, 3), ('big', 'amod', 'JJ', 1, 4), ('.', 'punct', '.', 0, 6)]
# [('she', 'nsubj', 'PRP', 0, 0), ('is', 'aux', 'VBZ', 0, 1), ('dog', 'dative', 'NN', 0, 4), ('the', 'det', 'DT', 1, 3), ('ball', 'dobj', 'NN', 0, 7), ('the', 'det', 'DT', 1, 5), ('big', 'amod', 'JJ', 1, 6), ('.', 'punct', '.', 0, 8)]
# [('she', 'nsubj', 'PRP', 0, 0), ('had', 'aux', 'VBD', 0, 1), ('me', 'dative', 'PRP', 0, 3), ('ball', 'dobj', 'NN', 0, 5), ('the', 'det', 'DT', 1, 4), ('.', 'punct', '.', 0, 6)]
# [('she', 'nsubj', 'PRP', 0, 0), ('has', 'aux', 'VBZ', 0, 1), ('mommy', 'dative', 'NN', 0, 3), ('ball', 'dobj', 'NN', 0, 5), ('the', 'det', 'DT', 1, 4)]
# [('she', 'nsubj', 'PRP', 0, 0), ('ball', 'dobj', 'NN', 0, 3), ('the', 'det', 'DT', 1, 2), ('to', 'dative', 'IN', 0, 4), ('me', 'pobj', 'PRP', 1, 5), ('.', 'punct', '.', 0, 6)]
# [('she', 'nsubj', 'PRP', 0, 0), ('ball', 'dobj', 'NN', 0, 3), ('the', 'det', 'DT', 1, 2), ('to', 'prep', 'IN', 0, 4), ('mom', 'pobj', 'NN', 1, 5), ('.', 'punct', '.', 0, 6)]
# [('she', 'nsubj', 'PRP', 0, 0), ('book', 'dobj', 'NN', 0, 4), ('the', 'det', 'DT', 1, 2), ('big', 'amod', 'JJ', 1, 3), ('to', 'dative', 'IN', 0, 5), ('grandma', 'pobj', 'NN', 1, 6), ('.', 'punct', '.', 0, 7)]
# [('she', 'nsubj', 'PRP', 0, 0), ('is', 'aux', 'VBZ', 0, 1), ('ball', 'dobj', 'NN', 0, 5), ('the', 'det', 'DT', 1, 3), ('big', 'amod', 'JJ', 1, 4), ('to', 'dative', 'IN', 0, 6), ('dog', 'pobj', 'NN', 1, 8), ('the', 'det', 'DT', 2, 7), ('.', 'punct', '.', 0, 9)]
# [('she', 'nsubj', 'PRP', 0, 0), ('had', 'aux', 'VBD', 0, 1), ('ball', 'dobj', 'NN', 0, 4), ('the', 'det', 'DT', 1, 3), ('to', 'dative', 'IN', 0, 5), ('me', 'pobj', 'PRP', 1, 6), ('.', 'punct', '.', 0, 7)]

# %%
dos, pps
# Out:
# (['she gave me the ball.',
#   'she gave mom the ball.',
#   'she sent grandma the big book.',
#   'she is tossing the dog the big ball.',
#   'she had given me the ball.',
#   'she has given mommy the ball'],
#  ['she gave the ball to me.',
#   'she gave the ball to mom.',
#   'she sent the big book to grandma.',
#   'she is tossing the big ball to the dog.',
#   'she had given the ball to me.'])

# %%
do_examples = [
    "she gave me the ball.",
    "she gave mom the ball.",
    "she sent grandma the big book.",
    "she is tossing the dog the big ball.",
    "she had given me the ball.",
    "she has given mommy the ball"
]

pp_examples = [
    "she gave the ball to me.",
    "she gave the ball to mom.",
    "she sent the big book to grandma.",
    "she is tossing the big ball to the dog.",
    "she had given the ball to me.",
]

do_postags = []

do_tags = get_postags(do_examples, 4, nlp)

for j, item in enumerate(do_tags):
    # print(j, item)
    if item == []:
        do_postags.append("")
    else:
        tokens, pos_tags = list(zip(*item))
        pos_string = " ".join(pos_tags)
        do_postags.append(pos_string)

pp_postags = []

pp_tags = get_postags(pp_examples, 4, nlp)

for j, item in enumerate(pp_tags):
    # print(j, item)
    if item == []:
        pp_postags.append("")
    else:
        tokens, pos_tags = list(zip(*item))
        pos_string = " ".join(pos_tags)
        pp_postags.append(pos_string)
# Out:
# 6it [00:00, 273.99it/s]
# 5it [00:00, 275.22it/s]

# %%
# get linearized postags
for dp in do_postags:
    print(dp)
# Out:
# PRP VBD PRP DT NN .
# PRP VBD NN DT NN .
# PRP VBD NN DT JJ NN .
# PRP VBZ VBG DT NN DT JJ NN .
# PRP VBD VBN PRP DT NN .

# %%
do_regex = re.compile(r"(VBD|VBZ VBG|VBD VBN|VBN) (DT\s|DT JJ\s)?(PRP|NN|NNP|NNPS|NNS) (DT\s|DT JJ\s)?(PRP|NN|NNP|NNPS|NNS)")

pp_regex = re.compile(r"(VBD|VBZ VBG|VBD VBN|VBN) (DT\s|DT JJ\s)?(PRP|NN|NNP|NNPS|NNS) IN (DT\s|DT JJ\s)?(PRP|NN|NNP|NNPS|NNS)")

# %%
childes_do = []
childes_pp = []

for i, item in enumerate(tqdm(postags)):
    do_match = do_regex.search(item)
    pp_match = pp_regex.search(item)
    if do_match:
        childes_do.append((corpus[i], item, do_match))
    if pp_match:
        childes_pp.append((corpus[i], item, pp_match))
# Out:
#   0%|          | 0/763989 [00:00<?, ?it/s]
# 100%|██████████| 763989/763989 [00:00<00:00, 1600973.91it/s]

# %%
len(childes_do), len(childes_pp)
# Out:
# (4738, 4050)

# %%
childes_pp
# Out:
# [('it was a piece of a hanger .',
#   'PRP VBD DT NN IN DT NN .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ("you've got it in your mouth like that .",
#   'PRP VBP VBN PRP IN PRP$ NN IN DT .',
#   <re.Match object; span=(8, 22), match='VBN PRP IN PRP'>),
#  ('that was grandma on the phone !',
#   'DT VBD NN IN DT NN .',
#   <re.Match object; span=(3, 18), match='VBD NN IN DT NN'>),
#  ('have you about had it with the rings .',
#   'VBP PRP RB VBN PRP IN DT NNS .',
#   <re.Match object; span=(11, 27), match='VBN PRP IN DT NN'>),
#  ('there you got him by the nose .',
#   'RB PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(7, 23), match='VBD PRP IN DT NN'>),
#  ('i put some chocolate on you .',
#   'PRP VBD DT NN IN PRP .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ('you bumped yourself in the mouth .',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('i heard catherine say they put the tiger in the zoo !',
#   'PRP VBD NNP VB PRP VBD DT NN IN DT NN .',
#   <re.Match object; span=(19, 37), match='VBD DT NN IN DT NN'>),
#  ('this old man he played one he played knickknack on my drum with a knickknack paddywack give a dog a bone this old man came rolling home .',
#   'DT JJ NN PRP VBD CD PRP VBD NN IN PRP$ NN IN DT NN NN VB DT NN DT NN DT JJ NN VBD VBG RB .',
#   <re.Match object; span=(24, 37), match='VBD NN IN PRP'>),
#  ('oh the baby clonked you on the head .',
#   'UH DT NN VBD PRP IN DT NN .',
#   <re.Match object; span=(9, 25), match='VBD PRP IN DT NN'>),
#  ('oh good job you put him on top .',
#   'UH JJ NN PRP VBD PRP IN NN .',
#   <re.Match object; span=(13, 26), match='VBD PRP IN NN'>),
#  ('we ran too far and swam too far out and the storm brought them to the beach on the other side of the ocean .',
#   'PRP VBD RB RB CC VBD RB RB RB CC DT NN VBD PRP IN DT NN IN DT JJ NN IN DT NN .',
#   <re.Match object; span=(39, 55), match='VBD PRP IN DT NN'>),
#  ('joseph is missing a lot of his blocks .',
#   'NNP VBZ VBG DT NN IN PRP$ NNS .',
#   <re.Match object; span=(4, 24), match='VBZ VBG DT NN IN PRP'>),
#  ('you got a lot of sneezies today ah achoo !',
#   'PRP VBD DT NN IN NNS NN UH UH .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ("you've got sand in your neck .",
#   'PRP VBP VBD NN IN PRP$ NN .',
#   <re.Match object; span=(8, 21), match='VBD NN IN PRP'>),
#  ('was that hard work for you ?',
#   'VBD DT JJ NN IN PRP .',
#   <re.Match object; span=(0, 19), match='VBD DT JJ NN IN PRP'>),
#  ('oh you saw another toy of yours ?',
#   'UH PRP VBD DT NN IN PRP .',
#   <re.Match object; span=(7, 23), match='VBD DT NN IN PRP'>),
#  ("let's make sure he got the paper about your picture .",
#   'VB PRP VB JJ PRP VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(17, 33), match='VBD DT NN IN PRP'>),
#  ('grandma cut them and catherine put them in the water .',
#   'NNP VBD PRP CC NNP VBD PRP IN DT NN .',
#   <re.Match object; span=(19, 35), match='VBD PRP IN DT NN'>),
#  ("and he's got a couple in each hand just for good luck .",
#   'CC PRP VBZ VBN DT NN IN DT NN RB IN JJ NN .',
#   <re.Match object; span=(11, 29), match='VBN DT NN IN DT NN'>),
#  ("man he's got a lot of legos .",
#   'UH PRP VBZ VBN DT NN IN NNS .',
#   <re.Match object; span=(11, 26), match='VBN DT NN IN NN'>),
#  ("yeah but they can't i told them at the end of that .",
#   'UH CC PRP MD RB PRP VBD PRP IN DT NN IN DT .',
#   <re.Match object; span=(20, 36), match='VBD PRP IN DT NN'>),
#  ('was it in their eyes ?',
#   'VBD PRP IN PRP$ NNS .',
#   <re.Match object; span=(0, 14), match='VBD PRP IN PRP'>),
#  ('thomas and catherine made a little bit of a mess out of their toys huh .',
#   'NNP CC NNP VBD DT JJ NN IN DT NN IN IN PRP$ NNS UH .',
#   <re.Match object; span=(11, 32), match='VBD DT JJ NN IN DT NN'>),
#  ('that was a special treat because mommy and daddy were so tired and they just wanted to sleep a little bit more .',
#   'DT VBD DT JJ NN IN NN CC NN VBD RB JJ CC PRP RB VBD TO VB DT JJ NN RBR .',
#   <re.Match object; span=(3, 21), match='VBD DT JJ NN IN NN'>),
#  ("you've got a lot of drool baby .",
#   'PRP VBP VBN DT NN IN NN NN .',
#   <re.Match object; span=(8, 23), match='VBN DT NN IN NN'>),
#  ('they put him in the bathtub !',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('miss lucy called the lady with the alligator purse .',
#   'NNP NNP VBD DT NN IN DT NN NN .',
#   <re.Match object; span=(8, 26), match='VBD DT NN IN DT NN'>),
#  ('oh mommy made a mess before i even got it built i dropped it over .',
#   'UH NN VBD DT NN IN PRP RB VBD PRP VBN PRP VBD PRP RP .',
#   <re.Match object; span=(6, 22), match='VBD DT NN IN PRP'>),
#  ('he just spilled it across the floor and then he picks the whole thing up .',
#   'PRP RB VBD PRP IN DT NN CC RB PRP VBZ DT JJ NN RP .',
#   <re.Match object; span=(7, 23), match='VBD PRP IN DT NN'>),
#  ("shouldn'ta given it to me .",
#   'RB VBN PRP IN PRP .',
#   <re.Match object; span=(3, 17), match='VBN PRP IN PRP'>),
#  ("look your baby bear's got a bottle like you do .",
#   'VB PRP$ NN NN VBZ VBN DT NN IN PRP VBP .',
#   <re.Match object; span=(18, 34), match='VBN DT NN IN PRP'>),
#  ('i picked a couple of things .',
#   'PRP VBD DT NN IN NNS .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('what would you do if i put you in the box ?',
#   'WP MD PRP VB IN PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(20, 36), match='VBD PRP IN DT NN'>),
#  ('okay put it on the ring .',
#   'UH VBD PRP IN DT NN .',
#   <re.Match object; span=(3, 19), match='VBD PRP IN DT NN'>),
#  ('you threw her on the ground .',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('oh and then you dropped it on her .',
#   'UH CC RB PRP VBD PRP IN PRP .',
#   <re.Match object; span=(13, 27), match='VBD PRP IN PRP'>),
#  ('mother got lipstick on your head .',
#   'NN VBD NN IN PRP$ NN .',
#   <re.Match object; span=(3, 16), match='VBD NN IN PRP'>),
#  ("he's got a big puddle of spit up on your bed .",
#   'PRP VBZ VBD DT JJ NN IN NN RP IN PRP$ NN .',
#   <re.Match object; span=(8, 26), match='VBD DT JJ NN IN NN'>),
#  ("yup and grandma just washed that pink blanket for you didn't she last time she was here .",
#   'UH CC NN RB VBD DT JJ NN IN PRP VBD RB PRP JJ NN PRP VBD RB .',
#   <re.Match object; span=(12, 31), match='VBD DT JJ NN IN PRP'>),
#  ('thank you you gave it to me .',
#   'VBP PRP PRP VBD PRP IN PRP .',
#   <re.Match object; span=(12, 26), match='VBD PRP IN PRP'>),
#  ('yeah ehe look at that you put them on a little plate .',
#   'UH UH VB IN DT PRP VBD PRP IN DT JJ NN .',
#   <re.Match object; span=(19, 38), match='VBD PRP IN DT JJ NN'>),
#  ('wanna put it on my foot .',
#   'PRP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ("because daddy we wouldn't have hung them on that rack unless they had probably gotten spit up on or something like that .",
#   'IN NN PRP MD RB VB VBN PRP IN DT NN IN PRP VBD RB VBN VBN RP IN CC NN IN DT .',
#   <re.Match object; span=(19, 35), match='VBN PRP IN DT NN'>),
#  ("i think somebody gave it to us i don't remember who .",
#   'PRP VBP NN VBD PRP IN PRP PRP VBP RB VB WP .',
#   <re.Match object; span=(11, 25), match='VBD PRP IN PRP'>),
#  ("well i think daddy's making some breakfast for us .",
#   'UH PRP VBP NN VBZ VBG DT NN IN PRP .',
#   <re.Match object; span=(14, 34), match='VBZ VBG DT NN IN PRP'>),
#  ('when you threw it at me ?',
#   'WRB PRP VBD PRP IN PRP .',
#   <re.Match object; span=(8, 22), match='VBD PRP IN PRP'>),
#  ("look at all the ones i have i've got a big pile of ones that you gave me ?",
#   'VB IN PDT DT NNS PRP VBP PRP VBP VBN DT JJ NN IN NNS WDT PRP VBD PRP .',
#   <re.Match object; span=(33, 51), match='VBN DT JJ NN IN NN'>),
#  ("let's see in one of these bags mommy bought some stuff for your cheeks here it is .",
#   'VB PRP VB IN CD IN DT NNS NN VBD DT NN IN PRP$ NNS RB PRP VBZ .',
#   <re.Match object; span=(29, 45), match='VBD DT NN IN PRP'>),
#  ('i thought it looked like there were a lot of cars was it .',
#   'PRP VBD PRP VBD IN EX VBD DT NN IN NNS VBD PRP .',
#   <re.Match object; span=(22, 37), match='VBD DT NN IN NN'>),
#  ("oh you think she's back in chicago well we saw in chica di w no where did we see her thomas we saw her in columbus ohio remember ?",
#   'UH PRP VBP PRP VBZ RB IN NNP UH PRP VBD IN NNP NNP NNP UH WRB VBD PRP VB PRP$ NNP PRP VBD PRP IN NNP NNP VB .',
#   <re.Match object; span=(86, 99), match='VBD PRP IN NN'>),
#  ('well you threw him on the floor you threw your panda bear friend on the f .',
#   'UH PRP VBD PRP IN DT NN PRP VBD PRP$ NN NN NN IN DT NN .',
#   <re.Match object; span=(7, 23), match='VBD PRP IN DT NN'>),
#  ('you put them on your head .',
#   'PRP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ("and it's got the baba in it too okay .",
#   'CC PRP VBZ VBN DT NN IN PRP RB UH .',
#   <re.Match object; span=(11, 27), match='VBN DT NN IN PRP'>),
#  ("we haven't played this game in a long time have we ?",
#   'PRP VBP RB VBN DT NN IN DT JJ NN VBP PRP .',
#   <re.Match object; span=(11, 32), match='VBN DT NN IN DT JJ NN'>),
#  ('it hit you in the head .',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('yes that was daddy on the phone .',
#   'UH DT VBD NN IN DT NN .',
#   <re.Match object; span=(6, 21), match='VBD NN IN DT NN'>),
#  ('and put you to sleep .',
#   'CC VBD PRP IN NN .',
#   <re.Match object; span=(3, 16), match='VBD PRP IN NN'>),
#  ('this one has got shapes in it .',
#   'DT NN VBZ VBN NNS IN PRP .',
#   <re.Match object; span=(10, 24), match='VBN NNS IN PRP'>),
#  ("see it's got shapes in it .",
#   'UH PRP VBZ VBN NNS IN PRP .',
#   <re.Match object; span=(11, 25), match='VBN NNS IN PRP'>),
#  ('you put it on your hand .',
#   'PRP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ("you put it on your hand didn't you .",
#   'PRP VBD PRP IN PRP$ NN VBD RB PRP .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ("they've got elephants on them don't they .",
#   'PRP VBP VBN NNS IN PRP VBP RB PRP .',
#   <re.Match object; span=(8, 22), match='VBN NNS IN PRP'>),
#  ("he's got a big nose like dumbo .",
#   'PRP VBZ VBN DT JJ NN IN NNP .',
#   <re.Match object; span=(8, 26), match='VBN DT JJ NN IN NN'>),
#  ('you put it on your hand .',
#   'PRP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('you put it on your hand .',
#   'PRP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ("it's got a set of eyes .",
#   'PRP VBZ VBN DT NN IN NNS .',
#   <re.Match object; span=(8, 23), match='VBN DT NN IN NN'>),
#  ("you've got a big bird at home .",
#   'PRP VBP VBN DT JJ NN IN NN .',
#   <re.Match object; span=(8, 26), match='VBN DT JJ NN IN NN'>),
#  ('you put it in the oven for .',
#   'PRP VBD PRP IN DT NN IN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ("that egg's got a rattle in it .",
#   'DT NN VBZ VBN DT NN IN PRP .',
#   <re.Match object; span=(10, 26), match='VBN DT NN IN PRP'>),
#  ('wanna put him in his chair .',
#   'NNP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('wanna put him in his chair .',
#   'NNP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('put it on the ground .',
#   'VBD PRP IN DT NN .',
#   <re.Match object; span=(0, 16), match='VBD PRP IN DT NN'>),
#  ('we saw penguins at the mall the other day .',
#   'PRP VBD NNS IN DT NN DT JJ NN .',
#   <re.Match object; span=(4, 20), match='VBD NNS IN DT NN'>),
#  ('where was he at the other day ?',
#   'WRB VBD PRP IN DT JJ NN .',
#   <re.Match object; span=(4, 23), match='VBD PRP IN DT JJ NN'>),
#  ("you cried when i put you on santa's lap .",
#   'PRP VBD WRB PRP VBD PRP IN NNP POS NN .',
#   <re.Match object; span=(16, 29), match='VBD PRP IN NN'>),
#  ("it's got a hole in the middle though .",
#   'PRP VBZ VBN DT NN IN DT NN RB .',
#   <re.Match object; span=(8, 26), match='VBN DT NN IN DT NN'>),
#  ("i don't know why but it's got a hole in the middle .",
#   'PRP VBP RB VB WRB CC PRP VBZ VBN DT NN IN DT NN .',
#   <re.Match object; span=(29, 47), match='VBN DT NN IN DT NN'>),
#  ("it's got a hole in the middle though .",
#   'PRP VBZ VBN DT NN IN DT NN RB .',
#   <re.Match object; span=(8, 26), match='VBN DT NN IN DT NN'>),
#  ("i don't know why but it's got a hole in the middle .",
#   'PRP VBP RB VB WRB CC PRP VBZ VBN DT NN IN DT NN .',
#   <re.Match object; span=(29, 47), match='VBN DT NN IN DT NN'>),
#  ('i put the hippo in your bed .',
#   'PRP VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ('oh you put it in your mouth .',
#   'UH PRP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(7, 21), match='VBD PRP IN PRP'>),
#  ('oh you got me with the pillow .',
#   'UH PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(7, 23), match='VBD PRP IN DT NN'>),
#  ('you got me with the pillow .',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('how about a little hard boiled egg on the side ?',
#   'WRB IN DT JJ RB VBN NN IN DT NN .',
#   <re.Match object; span=(16, 31), match='VBN NN IN DT NN'>),
#  ('you already took the sock off that shoe .',
#   'PRP RB VBD DT NN IN DT NN .',
#   <re.Match object; span=(7, 25), match='VBD DT NN IN DT NN'>),
#  ('he did a big day in the train yard .',
#   'PRP VBD DT JJ NN IN DT NN NN .',
#   <re.Match object; span=(4, 25), match='VBD DT JJ NN IN DT NN'>),
#  ('thomas played with the children and he had lots of fun .',
#   'NNP VBD IN DT NNS CC PRP VBD NNS IN NN .',
#   <re.Match object; span=(25, 38), match='VBD NNS IN NN'>),
#  ("you haven't seen this book in a long time .",
#   'PRP VBP RB VBN DT NN IN DT JJ NN .',
#   <re.Match object; span=(11, 32), match='VBN DT NN IN DT JJ NN'>),
#  ('how about and take the farm and put it in your room and put the dollhouse in your room ?',
#   'WRB IN CC VB DT NN CC VB PRP IN PRP$ NN CC VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(43, 59), match='VBD DT NN IN PRP'>),
#  ("good job joseph look thomas he's doing it he's putting them in the holes .",
#   'JJ NN NNP VB NNP PRP VBZ VBG PRP PRP VBZ VBG PRP IN DT NNS .',
#   <re.Match object; span=(37, 57), match='VBZ VBG PRP IN DT NN'>),
#  ("now that they've all left you because they didn't want to play with you .",
#   'RB IN PRP VBP DT VBN PRP IN PRP VBD RB VB TO VB IN PRP .',
#   <re.Match object; span=(17, 31), match='VBN PRP IN PRP'>),
#  ('saw a lot of them earlier maybe at the other feeder .',
#   'VBD DT NN IN PRP RBR RB IN DT JJ NN .',
#   <re.Match object; span=(0, 16), match='VBD DT NN IN PRP'>),
#  ("oh she's got shoes on the sister .",
#   'UH PRP VBZ VBD NNS IN DT NN .',
#   <re.Match object; span=(11, 27), match='VBD NNS IN DT NN'>),
#  ('you clunked me on the head with the ball .',
#   'PRP VBD PRP IN DT NN IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('ah she put it on my face .',
#   'UH PRP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(7, 21), match='VBD PRP IN PRP'>),
#  ('i found it in the other room somewhere .',
#   'PRP VBD PRP IN DT JJ NN RB .',
#   <re.Match object; span=(4, 23), match='VBD PRP IN DT JJ NN'>),
#  ("you having trouble getting that out that's because i put it in the zipper compartment .",
#   'PRP VBG NN VBG DT RP DT VBZ IN PRP VBD PRP IN DT NN NN .',
#   <re.Match object; span=(35, 51), match='VBD PRP IN DT NN'>),
#  ('that was a big clunk on the floor .',
#   'DT VBD DT JJ NN IN DT NN .',
#   <re.Match object; span=(3, 24), match='VBD DT JJ NN IN DT NN'>),
#  ('there was a hair in your mouth .',
#   'EX VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(3, 19), match='VBD DT NN IN PRP'>),
#  ("this stuff is yucky it's all slimy and you dropped it on the floor .",
#   'DT NN VBZ JJ PRP VBZ RB JJ CC PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(34, 50), match='VBD PRP IN DT NN'>),
#  ('found a crooked sixpence against a crooked stile .',
#   'VBD DT JJ NN IN DT JJ NN .',
#   <re.Match object; span=(0, 24), match='VBD DT JJ NN IN DT JJ NN'>),
#  ('she got a kiss from her mama .',
#   'PRP VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ('she put him in a bathtub to see if he could swim ?',
#   'PRP VBD PRP IN DT NN TO VB IN PRP MD VB .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('she told me that she understood the telephone before i knew it she got one for her birthday and she opened the box and just sitting she picked up the telephone and said hi !',
#   'PRP VBD PRP IN PRP VBD DT NN IN PRP VBD PRP PRP VBD NN IN PRP$ NN CC PRP VBD DT NN CC RB VBG PRP VBD RP DT NN CC VBD UH .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('wanna put the daddy in bed .',
#   'PRP VBD DT NN IN NN .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('you put the boy in the car .',
#   'PRP VBD DT NN IN DT NN .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('you said morning to me without the good this morning .',
#   'PRP VBD NN IN PRP IN DT NN DT NN .',
#   <re.Match object; span=(4, 17), match='VBD NN IN PRP'>),
#  ("aha no she's putting it down my shirt .",
#   'UH UH PRP VBZ VBG PRP IN PRP$ NN .',
#   <re.Match object; span=(10, 28), match='VBZ VBG PRP IN PRP'>),
#  ('glen is holding naima in that picture .',
#   'NNP VBZ VBG NNP IN DT NN .',
#   <re.Match object; span=(4, 24), match='VBZ VBG NNP IN DT NN'>),
#  ('glen is holding you in that picture .',
#   'NNP VBZ VBG PRP IN DT NN .',
#   <re.Match object; span=(4, 24), match='VBZ VBG PRP IN DT NN'>),
#  ('i put the top on the apples .',
#   'PRP VBD DT NN IN DT NNS .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('oh boy that was a lot of plastic .',
#   'UH UH DT VBD DT NN IN NN .',
#   <re.Match object; span=(9, 24), match='VBD DT NN IN NN'>),
#  ('mommy spilled the water on the floor .',
#   'NN VBD DT NN IN DT NN .',
#   <re.Match object; span=(3, 21), match='VBD DT NN IN DT NN'>),
#  ('glad we brought the whole household of apple juice .',
#   'JJ PRP VBD DT JJ NN IN NN NN .',
#   <re.Match object; span=(7, 25), match='VBD DT JJ NN IN NN'>),
#  ('made a mustache on your face .',
#   'VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(0, 16), match='VBD DT NN IN PRP'>),
#  ('you made a mustache on it .',
#   'PRP VBD DT NN IN PRP .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ("the camera's taking pictures of michael ?",
#   'DT NN VBZ VBG NNS IN NNP .',
#   <re.Match object; span=(6, 23), match='VBZ VBG NNS IN NN'>),
#  ("he's eating cereal from a bowl .",
#   'PRP VBZ VBG NN IN DT NN .',
#   <re.Match object; span=(4, 23), match='VBZ VBG NN IN DT NN'>),
#  ("he's swinging him he threw him in the air up in the air !",
#   'PRP VBZ VBG PRP PRP VBD PRP IN DT NN IN IN DT NN .',
#   <re.Match object; span=(20, 36), match='VBD PRP IN DT NN'>),
#  ('now he said baba for the body lotion .',
#   'RB PRP VBD NNP IN DT NN NN .',
#   <re.Match object; span=(7, 23), match='VBD NNP IN DT NN'>),
#  ('i hit you in the head .',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('we saw a polar bear at the zoo too .',
#   'PRP VBD DT JJ NN IN DT NN RB .',
#   <re.Match object; span=(4, 25), match='VBD DT JJ NN IN DT NN'>),
#  ('so she called an ambulance and they took gaspard to the hospital .',
#   'RB PRP VBD DT NN CC PRP VBD NNP IN DT NN .',
#   <re.Match object; span=(24, 40), match='VBD NNP IN DT NN'>),
#  ('the nurse took off my scarf and put a white gown on me .',
#   'DT NN VBD RP PRP$ NN CC VBD DT JJ NN IN PRP .',
#   <re.Match object; span=(24, 43), match='VBD DT JJ NN IN PRP'>),
#  ('but i was still a little scared especially when she took me to the x ray room .',
#   'CC PRP VBD RB DT JJ JJ RB WRB PRP VBD PRP IN DT NN NN NN .',
#   <re.Match object; span=(34, 50), match='VBD PRP IN DT NN'>),
#  ('okay you read it to mama .',
#   'UH PRP VBD PRP IN NN .',
#   <re.Match object; span=(7, 20), match='VBD PRP IN NN'>),
#  ('rachel put the ball on the chair .',
#   'NNP VBD DT NN IN DT NN .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('rachel put the ball on the chair .',
#   'NNP VBD DT NN IN DT NN .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('mommy threw the ball to rachel .',
#   'NN VBD DT NN IN NNP .',
#   <re.Match object; span=(3, 18), match='VBD DT NN IN NN'>),
#  ('mommy threw it to rachel .',
#   'NN VBD PRP IN NNP .',
#   <re.Match object; span=(3, 16), match='VBD PRP IN NN'>),
#  ("she's got a hat on aislinn .",
#   'PRP VBZ VBD DT NN IN NNP .',
#   <re.Match object; span=(8, 23), match='VBD DT NN IN NN'>),
#  ("oh because it's got a brush on it .",
#   'UH IN PRP VBZ VBN DT NN IN PRP .',
#   <re.Match object; span=(14, 30), match='VBN DT NN IN PRP'>),
#  ('did you drink the water i gave you by the way .',
#   'VBD PRP VB DT NN PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(21, 37), match='VBD PRP IN DT NN'>),
#  ("the turkey's wearing a shirt like pants .",
#   'DT NNP VBZ VBG DT NN IN NNS .',
#   <re.Match object; span=(7, 26), match='VBZ VBG DT NN IN NN'>),
#  ("turkey's wearing a shoe on his head ?",
#   'NNP VBZ VBG DT NN IN PRP$ NN .',
#   <re.Match object; span=(4, 24), match='VBZ VBG DT NN IN PRP'>),
#  ("the little camera's taking pictures of you .",
#   'DT JJ NN VBZ VBG NNS IN PRP .',
#   <re.Match object; span=(9, 27), match='VBZ VBG NNS IN PRP'>),
#  ('wanna put it in the box .',
#   'NNP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ("you've got a little bit of milk here .",
#   'PRP VBP VBN DT JJ NN IN NN RB .',
#   <re.Match object; span=(8, 26), match='VBN DT JJ NN IN NN'>),
#  ('oh you got it in time .',
#   'UH PRP VBD PRP IN NN .',
#   <re.Match object; span=(7, 20), match='VBD PRP IN NN'>),
#  ("it's got egg in it and it's got milk everything you like .",
#   'PRP VBZ VBN NN IN PRP CC PRP VBZ VBN NN NN PRP VBP .',
#   <re.Match object; span=(8, 21), match='VBN NN IN PRP'>),
#  ('cause i stole it from you .',
#   'IN PRP VBD PRP IN PRP .',
#   <re.Match object; span=(7, 21), match='VBD PRP IN PRP'>),
#  ('you found some stuff on the floor ?',
#   'PRP VBD DT NN IN DT NN .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('oh you put it on me .',
#   'UH PRP VBD PRP IN PRP .',
#   <re.Match object; span=(7, 21), match='VBD PRP IN PRP'>),
#  ('you did it by yourself .',
#   'PRP VBD PRP IN PRP .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ("there's a different guy named mark at my school ?",
#   'EX VBZ DT JJ NN VBN NNP IN PRP$ NN .',
#   <re.Match object; span=(16, 30), match='VBN NNP IN PRP'>),
#  ('the elephant sneezed and fell to his knees and that was the end of the monk the monk the monk ?',
#   'DT NN VBD CC VBD IN PRP$ NNS CC DT VBD DT NN IN DT NN DT NN DT NN .',
#   <re.Match object; span=(35, 53), match='VBD DT NN IN DT NN'>),
#  ('and that was the end of the monk ?',
#   'CC DT VBD DT NN IN DT NN .',
#   <re.Match object; span=(6, 24), match='VBD DT NN IN DT NN'>),
#  ('we got a lot of these bags huh ?',
#   'PRP VBD DT NN IN DT NNS UH .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('you made a hole with your hand .',
#   'PRP VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ('you made a mess with the bubbles .',
#   'PRP VBD DT NN IN DT NNS .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ("i got a book about a cat let's see if i can find the book about the cat here it is .",
#   'PRP VBD DT NN IN DT NN VB PRP VB IN PRP MD VB DT NN IN DT NN RB PRP VBZ .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('you just blew a bubble outta your mouth .',
#   'PRP RB VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(7, 23), match='VBD DT NN IN PRP'>),
#  ("should've got coffee from jack's .",
#   'MD VB VBN NN IN NNP POS .',
#   <re.Match object; span=(6, 18), match='VBN NN IN NN'>),
#  ('i wonder if he found any coffee at the store .',
#   'PRP VBP IN PRP VBD DT NN IN DT NN .',
#   <re.Match object; span=(15, 33), match='VBD DT NN IN DT NN'>),
#  ('i just heard the noise of the car coming back .',
#   'PRP RB VBD DT NN IN DT NN VBG RB .',
#   <re.Match object; span=(7, 25), match='VBD DT NN IN DT NN'>),
#  ('you found it at the store or not .',
#   'PRP VBD PRP IN DT NN CC RB .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ("where is it well he didn't find any coffee beans but he found a cup of coffee ?",
#   'WRB VBZ PRP UH PRP VBD RB VB DT NN NNS CC PRP VBD DT NN IN NN .',
#   <re.Match object; span=(46, 61), match='VBD DT NN IN NN'>),
#  ('he got a cup of coffee at the store .',
#   'PRP VBD DT NN IN NN IN DT NN .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ("you've got the cat by the tail swing that cat .",
#   'PRP VBP VBN DT NN IN DT NN VB DT NN .',
#   <re.Match object; span=(8, 26), match='VBN DT NN IN DT NN'>),
#  ("he's got the boat on his head .",
#   'PRP VBZ VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(8, 24), match='VBD DT NN IN PRP'>),
#  ("michael's wearing boots in this picture look what that dog is doing that dog looks like he's sleeping .",
#   'NNP VBZ VBG NNS IN DT NN VB WP DT NN VBZ VBG DT NN VBZ IN PRP VBZ VBG .',
#   <re.Match object; span=(4, 24), match='VBZ VBG NNS IN DT NN'>),
#  ('you saw the ducks on saturday .',
#   'PRP VBD DT NNS IN NNP .',
#   <re.Match object; span=(4, 20), match='VBD DT NNS IN NN'>),
#  ("that's got a zipper on the other side sweetie pie .",
#   'DT VBZ VBN DT NN IN DT JJ NN NNP NNP .',
#   <re.Match object; span=(7, 28), match='VBN DT NN IN DT JJ NN'>),
#  ('we posed you as buddha .',
#   'PRP VBD PRP IN NNP .',
#   <re.Match object; span=(4, 17), match='VBD PRP IN NN'>),
#  ("gabby's wearin a necklace with cheerios and fruit loops .",
#   'NNP VBZ VBG DT NN IN NNS CC NN NNS .',
#   <re.Match object; span=(4, 23), match='VBZ VBG DT NN IN NN'>),
#  ('he did it for you .',
#   'PRP VBD PRP IN PRP .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('peter piper picked a peck of pickle peppers a peck of pickle .',
#   'NNP NNP VBD DT NN IN NN NNS DT NN IN NN .',
#   <re.Match object; span=(8, 23), match='VBD DT NN IN NN'>),
#  ("peppers peter piper picked if peter piper picked a peck of pickle peppers where's the peck of pickle peppers peter piper picked .",
#   'NNS NNP NNP VBD IN NNP NNP VBD DT NN IN NN NNS WRB VBZ DT NN IN NN NNS NNP NNP VBD .',
#   <re.Match object; span=(27, 42), match='VBD DT NN IN NN'>),
#  ("and you've got a piece of puzzle in there too .",
#   'CC PRP VBP VBN DT NN IN NN RB RB RB .',
#   <re.Match object; span=(11, 26), match='VBN DT NN IN NN'>),
#  ('okay peter piper picked a peck of pickle peppers .',
#   'UH NNP NNP VBD DT NN IN NN NNS .',
#   <re.Match object; span=(11, 26), match='VBD DT NN IN NN'>),
#  ("if peter piper picked a peck of pickle peppers where's the peck of pickle peppers peter piper picked ?",
#   'IN NNP NNP VBD DT NN IN NN NNS WRB VBZ DT NN IN NN NNS NNP NNP VBD .',
#   <re.Match object; span=(11, 26), match='VBD DT NN IN NN'>),
#  ('peter piper picked a peck of pickle peppers .',
#   'NNP NNP VBD DT NN IN NN NNS .',
#   <re.Match object; span=(8, 23), match='VBD DT NN IN NN'>),
#  ("if peter piper picked a peck of pickle peppers where's the peck of pickle peppers peter piper picked .",
#   'IN NNP NNP VBD DT NN IN NN NNS WRB VBZ DT NN IN NN NNS NNP NNP VBD .',
#   <re.Match object; span=(11, 26), match='VBD DT NN IN NN'>),
#  ('peter piper picked a peck of pickle peppers .',
#   'NNP NNP VBD DT NN IN NN NNS .',
#   <re.Match object; span=(8, 23), match='VBD DT NN IN NN'>),
#  ("if peter piper picked a peck of pickle peppers where's the peck of pickle peppers peter piper picked .",
#   'IN NNP NNP VBD DT NN IN NN NNS WRB VBZ DT NN IN NN NNS NNP NNP VBD .',
#   <re.Match object; span=(11, 26), match='VBD DT NN IN NN'>),
#  ('we bought some blocks like this i was what abu cloth covered ones .',
#   'PRP VBD DT NNS IN DT PRP VBD WP NNP NN VBN NNS .',
#   <re.Match object; span=(4, 24), match='VBD DT NNS IN DT PRP'>),
#  ('doggie got a kiss from you !',
#   'NNP VBD DT NN IN PRP .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ('i got blocks at home .',
#   'PRP VBD NNS IN NN .',
#   <re.Match object; span=(4, 17), match='VBD NNS IN NN'>),
#  ('but that was a situation of her being up here and it being on the floor .',
#   'CC DT VBD DT NN IN PRP VBG RB RB CC PRP VBG IN DT NN .',
#   <re.Match object; span=(6, 22), match='VBD DT NN IN PRP'>),
#  ('i had a piece of kah on there .',
#   'PRP VBD DT NN IN NN IN RB .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('remember she took you to the play ground to the park .',
#   'VB PRP VBD PRP IN DT NN NN IN DT NN .',
#   <re.Match object; span=(7, 23), match='VBD PRP IN DT NN'>),
#  ('oh that truck is giving some dirt to that truck .',
#   'UH DT NN VBZ VBG DT NN IN DT NN .',
#   <re.Match object; span=(9, 31), match='VBZ VBG DT NN IN DT NN'>),
#  ("that was a lot of raisin for you wasn't it ?",
#   'DT VBD DT NN IN NN IN PRP VBD RB PRP .',
#   <re.Match object; span=(3, 18), match='VBD DT NN IN NN'>),
#  ("there was a dog at the play ground yesterday that's right .",
#   'EX VBD DT NN IN DT NN NN NN WDT VBZ JJ .',
#   <re.Match object; span=(3, 21), match='VBD DT NN IN DT NN'>),
#  ('and there were lots of babies there too right ?',
#   'CC EX VBD NNS IN NNS RB RB JJ .',
#   <re.Match object; span=(6, 19), match='VBD NNS IN NN'>),
#  ('she had an umbrella at her house .',
#   'PRP VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ('we played soccer at her house .',
#   'PRP VBD NN IN PRP$ NN .',
#   <re.Match object; span=(4, 17), match='VBD NN IN PRP'>),
#  ('then you had snacks in the car .',
#   'RB PRP VBD NNS IN DT NN .',
#   <re.Match object; span=(7, 23), match='VBD NNS IN DT NN'>),
#  ('and she gave them to mommy and mommy gave them to you and you ate them .',
#   'CC PRP VBD PRP IN NN CC NN VBD PRP IN PRP CC PRP VBD PRP .',
#   <re.Match object; span=(7, 20), match='VBD PRP IN NN'>),
#  ('oh that was a piece of wheat .',
#   'UH DT VBD DT NN IN NN .',
#   <re.Match object; span=(6, 21), match='VBD DT NN IN NN'>),
#  ("it's clifford's bedtime his mother helped him into bed .",
#   'PRP VBZ NNP POS NN PRP$ NN VBD PRP IN NN .',
#   <re.Match object; span=(27, 40), match='VBD PRP IN NN'>),
#  ("so i've got it on f one .",
#   'RB PRP VBP VBN PRP IN NN CD .',
#   <re.Match object; span=(11, 24), match='VBN PRP IN NN'>),
#  ("you've done that too yep she's putting seeds in the bird feeder with a spoon .",
#   'PRP VBP VBN DT RB UH PRP VBZ VBG NNS IN DT NN NN IN DT NN .',
#   <re.Match object; span=(25, 45), match='VBZ VBG NNS IN DT NN'>),
#  ('i boinked you in your belly button .',
#   'PRP VBD PRP IN PRP$ NN NN .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('correct you read the whole book by yourself .',
#   'JJ PRP VBD DT JJ NN IN PRP .',
#   <re.Match object; span=(7, 26), match='VBD DT JJ NN IN PRP'>),
#  ("she's got a funny thing on her head .",
#   'PRP VBZ VBD DT JJ NN IN PRP$ NN .',
#   <re.Match object; span=(8, 27), match='VBD DT JJ NN IN PRP'>),
#  ('oh i caught that piece of cereal .',
#   'UH PRP VBD DT NN IN NN .',
#   <re.Match object; span=(7, 22), match='VBD DT NN IN NN'>),
#  ('she gave him things she told him secrets and she sang lullabies to him every night .',
#   'PRP VBD PRP NNS PRP VBD PRP NNS CC PRP VBD NNS IN PRP DT NN .',
#   <re.Match object; span=(39, 53), match='VBD NNS IN PRP'>),
#  ('you saw her in new york .',
#   'PRP VBD PRP IN NNP NNP .',
#   <re.Match object; span=(4, 17), match='VBD PRP IN NN'>),
#  ('i saw a big piece on the floor that looked like a flower .',
#   'PRP VBD DT JJ NN IN DT NN WDT VBD IN DT NN .',
#   <re.Match object; span=(4, 25), match='VBD DT JJ NN IN DT NN'>),
#  ('eat eyes oh you made eyes in the playdoh !',
#   'UH NNS UH PRP VBD NNS IN DT NN .',
#   <re.Match object; span=(14, 30), match='VBD NNS IN DT NN'>),
#  ("when you wear your striped hat ethan's an engineer and he's taking a trip on his train ?",
#   'WRB PRP VBP PRP$ JJ NN NNP VBZ DT NN CC PRP VBZ VBG DT NN IN PRP$ NN .',
#   <re.Match object; span=(44, 64), match='VBZ VBG DT NN IN PRP'>),
#  ('she gave him things she told him secrets and sang lullabies to him every night .',
#   'PRP VBD PRP NNS PRP VBD PRP NNS CC VBD NNS IN PRP DT NN .',
#   <re.Match object; span=(35, 49), match='VBD NNS IN PRP'>),
#  ("this is lulu's baby brother he can say lulu hay you missed the picture of the lollipop .",
#   'DT VBZ NNP POS NN NN PRP MD VB NNP NNP PRP VBD DT NN IN DT NN .',
#   <re.Match object; span=(43, 61), match='VBD DT NN IN DT NN'>),
#  ('she gave him things she told him secrets and she sang lullabies to him every night .',
#   'PRP VBD PRP NNS PRP VBD PRP NNS CC PRP VBD NNS IN PRP DT NN .',
#   <re.Match object; span=(39, 53), match='VBD NNS IN PRP'>),
#  ('our classmates took pictures of us lots of pictures .',
#   'PRP$ NNS VBD NNS IN PRP NNS IN NNS .',
#   <re.Match object; span=(9, 23), match='VBD NNS IN PRP'>),
#  ("yeah it's hard to talk when you've got food in your mouth i know .",
#   'UH PRP VBZ JJ TO VB WRB PRP VBP VBN NN IN PRP$ NN PRP VBP .',
#   <re.Match object; span=(32, 45), match='VBN NN IN PRP'>),
#  ('i bet you shoveled a lot of rocks ?',
#   'PRP VBP PRP VBD DT NN IN NNS .',
#   <re.Match object; span=(12, 27), match='VBD DT NN IN NN'>),
#  ("i've got it for you .",
#   'PRP VBP VBD PRP IN PRP .',
#   <re.Match object; span=(8, 22), match='VBD PRP IN PRP'>),
#  ('and who did we see yesterday we saw a lot of people yesterday .',
#   'CC WP VBD PRP VB NN PRP VBD DT NN IN NNS NN .',
#   <re.Match object; span=(24, 39), match='VBD DT NN IN NN'>),
#  ('and put them in a little bag .',
#   'CC VBD PRP IN DT JJ NN .',
#   <re.Match object; span=(3, 22), match='VBD PRP IN DT JJ NN'>),
#  ("mommy's having toast with jam .",
#   'NN VBZ VBG NN IN NN .',
#   <re.Match object; span=(3, 19), match='VBZ VBG NN IN NN'>),
#  ('i cut another piece of cherry i put it on the spoon ?',
#   'PRP VBD DT NN IN NN PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('well he did it for you .',
#   'UH PRP VBD PRP IN PRP .',
#   <re.Match object; span=(7, 21), match='VBD PRP IN PRP'>),
#  ("and phoebe made that picture for you there's a big kittie cat .",
#   'CC NNP VBD DT NN IN PRP EX VBZ DT JJ NN NN .',
#   <re.Match object; span=(7, 23), match='VBD DT NN IN PRP'>),
#  ('ooh that was the end of the song .',
#   'UH DT VBD DT NN IN DT NN .',
#   <re.Match object; span=(6, 24), match='VBD DT NN IN DT NN'>),
#  ('huh and she put the piggy in the stroller .',
#   'UH CC PRP VBD DT NN IN DT NN .',
#   <re.Match object; span=(10, 28), match='VBD DT NN IN DT NN'>),
#  ("there's templeton after he ate everything at the fair ?",
#   'EX VBZ NNP IN PRP VBD NN IN DT NN .',
#   <re.Match object; span=(18, 33), match='VBD NN IN DT NN'>),
#  ('and she put him in the stroller and she take him for a ride with the dolly .',
#   'CC PRP VBD PRP IN DT NN CC PRP VBP PRP IN DT NN IN DT NN .',
#   <re.Match object; span=(7, 23), match='VBD PRP IN DT NN'>),
#  ('wanna put it on the monkey .',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('who made a big messy under their chair ?',
#   'WP VBD DT JJ NN IN PRP$ NN .',
#   <re.Match object; span=(3, 22), match='VBD DT JJ NN IN PRP'>),
#  ('peter piper picked a peck of pickle peppers .',
#   'NNP NNP VBD DT NN IN NN NNS .',
#   <re.Match object; span=(8, 23), match='VBD DT NN IN NN'>),
#  ("if peter piper picked a peck of pickle peppers where's the peck of pickle peppers peter piper picked .",
#   'IN NNP NNP VBD DT NN IN NN NNS WRB VBZ DT NN IN NN NNS NNP NNP VBD .',
#   <re.Match object; span=(11, 26), match='VBD DT NN IN NN'>),
#  ('one morning while donald duck was busy inventing things the wind blew a brick off the top of the chimney ?',
#   'CD NN IN NNP NNP VBD JJ VBG NNS DT NN VBD DT NN IN DT NN IN DT NN .',
#   <re.Match object; span=(38, 56), match='VBD DT NN IN DT NN'>),
#  ('its got a hole in it ?',
#   'PRP VBD DT NN IN PRP .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ("i'm put you on daddy's bed .",
#   'PRP VBP VBN PRP IN NN POS NN .',
#   <re.Match object; span=(8, 21), match='VBN PRP IN NN'>),
#  ('there was a bee in your hair ?',
#   'EX VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(3, 19), match='VBD DT NN IN PRP'>),
#  ('when you were with daddy and there was a bee in your hair ?',
#   'WRB PRP VBD IN NN CC EX VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(24, 40), match='VBD DT NN IN PRP'>),
#  ('yeah there was paper on it but i took it off you gonna draw something ?',
#   'UH EX VBD NN IN PRP CC PRP VBD PRP RP PRP TO TO VB NN .',
#   <re.Match object; span=(6, 19), match='VBD NN IN PRP'>),
#  ('you put them in a cup thank you .',
#   'PRP VBD PRP IN DT NN VBP PRP .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('oh there were bubbles at the carnival .',
#   'UH EX VBD NNS IN DT NN .',
#   <re.Match object; span=(6, 22), match='VBD NNS IN DT NN'>),
#  ("he's drinking it with gusto .",
#   'PRP VBZ VBG PRP IN NN .',
#   <re.Match object; span=(4, 21), match='VBZ VBG PRP IN NN'>),
#  ('i drank that juice with gusto .',
#   'PRP VBD DT NN IN NN .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('those are your added responsibilities for the day .',
#   'DT VBP PRP$ VBN NNS IN DT NN .',
#   <re.Match object; span=(12, 28), match='VBN NNS IN DT NN'>),
#  ('your mommy did needlepoint on that pillow .',
#   'PRP$ NN VBD NN IN DT NN .',
#   <re.Match object; span=(8, 23), match='VBD NN IN DT NN'>),
#  ('sure was a big sip of juice .',
#   'RB VBD DT JJ NN IN NN .',
#   <re.Match object; span=(3, 21), match='VBD DT JJ NN IN NN'>),
#  ('and put johnnie on a plane .',
#   'CC VBD NNP IN DT NN .',
#   <re.Match object; span=(3, 19), match='VBD NNP IN DT NN'>),
#  ('well he is having a little bit of problems here .',
#   'UH PRP VBZ VBG DT JJ NN IN NNS RB .',
#   <re.Match object; span=(7, 29), match='VBZ VBG DT JJ NN IN NN'>),
#  ('yeah there was a hair on the tray .',
#   'UH EX VBD DT NN IN DT NN .',
#   <re.Match object; span=(6, 24), match='VBD DT NN IN DT NN'>),
#  ('i put it in the bowl .',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('i cut it into a little piece .',
#   'PRP VBD PRP IN DT JJ NN .',
#   <re.Match object; span=(4, 23), match='VBD PRP IN DT JJ NN'>),
#  ('got a lot of water .',
#   'VBD DT NN IN NN .',
#   <re.Match object; span=(0, 15), match='VBD DT NN IN NN'>),
#  ("naima's giving it to mommy ?",
#   'NNP VBZ VBG PRP IN NN .',
#   <re.Match object; span=(4, 21), match='VBZ VBG PRP IN NN'>),
#  ('he ate cereal for breakfast .',
#   'PRP VBD NN IN NN .',
#   <re.Match object; span=(4, 16), match='VBD NN IN NN'>),
#  ('this was a big meal for you .',
#   'DT VBD DT JJ NN IN PRP .',
#   <re.Match object; span=(3, 22), match='VBD DT JJ NN IN PRP'>),
#  ('you want this cheese you asked me for cheese .',
#   'PRP VBP DT NN PRP VBD PRP IN NN .',
#   <re.Match object; span=(18, 31), match='VBD PRP IN NN'>),
#  ('there was a man on a bicycle just now did you see him .',
#   'EX VBD DT NN IN DT NN RB RB VBD PRP VB PRP .',
#   <re.Match object; span=(3, 21), match='VBD DT NN IN DT NN'>),
#  ('yep we cut the scapes off the garlic .',
#   'UH PRP VBD DT NNS IN DT NN .',
#   <re.Match object; span=(7, 26), match='VBD DT NNS IN DT NN'>),
#  ('i gave it to you ?',
#   'PRP VBD PRP IN PRP .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ("uh he was followed you down the stairs to go let's see ?",
#   'UH PRP VBD VBN PRP IN DT NNS TO VB VB PRP VB .',
#   <re.Match object; span=(7, 27), match='VBD VBN PRP IN DT NN'>),
#  ("i've got a lot of work to do .",
#   'PRP VBP VBN DT NN IN NN TO VB .',
#   <re.Match object; span=(8, 23), match='VBN DT NN IN NN'>),
#  ("he's hitting me in the belly ?",
#   'PRP VBZ VBG PRP IN DT NN .',
#   <re.Match object; span=(4, 24), match='VBZ VBG PRP IN DT NN'>),
#  ('it got you on the nose ?',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('you got it with your hand ?',
#   'PRP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('oh you got it with your finger that time ?',
#   'UH PRP VBD PRP IN PRP$ NN DT NN .',
#   <re.Match object; span=(7, 21), match='VBD PRP IN PRP'>),
#  ('you got it with your knuckle that time ?',
#   'PRP VBD PRP IN PRP$ NN DT NN .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ("mommy's holding naima in that picture .",
#   'NN VBZ VBG NNP IN DT NN .',
#   <re.Match object; span=(3, 23), match='VBZ VBG NNP IN DT NN'>),
#  ('oh we never saw the puppy inside that house at that party that day .',
#   'UH PRP RB VBD DT NN IN DT NN IN DT NN DT NN .',
#   <re.Match object; span=(10, 28), match='VBD DT NN IN DT NN'>),
#  ('you gave them to me thanks ?',
#   'PRP VBD PRP IN PRP NNS .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('stuck a feather in his cap and called it .',
#   'VBD DT NN IN PRP$ NN CC VBD PRP .',
#   <re.Match object; span=(0, 16), match='VBD DT NN IN PRP'>),
#  ('yeah it was a piece of fuzz .',
#   'UH PRP VBD DT NN IN NN .',
#   <re.Match object; span=(7, 22), match='VBD DT NN IN NN'>),
#  ('we saw a lot of babies at your party .',
#   'PRP VBD DT NN IN NNS IN PRP$ NN .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ("oh i've got someone at the door um .",
#   'UH PRP VBP VBN NN IN DT NN UH .',
#   <re.Match object; span=(11, 26), match='VBN NN IN DT NN'>),
#  ('she has spotted him in the photo .',
#   'PRP VBZ VBN PRP IN DT NN .',
#   <re.Match object; span=(8, 24), match='VBN PRP IN DT NN'>),
#  ('snow said the boy with the dog ?',
#   'NNP VBD DT NN IN DT NN .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ("it's only a snowflake said grandfather with the beard .",
#   'PRP VBZ RB DT NN VBD NN IN DT NN .',
#   <re.Match object; span=(17, 32), match='VBD NN IN DT NN'>),
#  ("that's nothing said the man with the hat .",
#   'DT VBZ NN VBD DT NN IN DT NN .',
#   <re.Match object; span=(10, 28), match='VBD DT NN IN DT NN'>),
#  ("it's snowing said the boy with the dog .",
#   'PRP VBZ VBG VBD DT NN IN DT NN .',
#   <re.Match object; span=(12, 30), match='VBD DT NN IN DT NN'>),
#  ('snow said the boy with his puppy ?',
#   'NNP VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ('that night lily drew a new picture of mr slinger and wrote a story about him too .',
#   'DT NN NNP VBD DT JJ NN IN NNP NNP CC VBD DT NN IN PRP RB .',
#   <re.Match object; span=(10, 28), match='VBD DT JJ NN IN NN'>),
#  ("lily was really really sorry hm lily's mother wrote a note and lily's father baked some tasty snacks for lily to take to school the next day .",
#   'NNP VBD RB RB JJ XX NNP POS NN VBD DT NN CC NNP POS NN VBD DT JJ NNS IN NNP TO VB IN NN DT JJ NN .',
#   <re.Match object; span=(55, 74), match='VBD DT JJ NNS IN NN'>),
#  ('i had a lot of fun and explored everywhere maybe i was going too fast but suddenly .',
#   'PRP VBD DT NN IN NN CC VBD RB RB PRP VBD VBG RB RB CC RB .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('is that where alex sat when he had lunch with you ?',
#   'VBZ DT WRB NNP VBD WRB PRP VBD NN IN PRP .',
#   <re.Match object; span=(27, 40), match='VBD NN IN PRP'>),
#  ('have you got some rocks in that shovel .',
#   'VBP PRP VBN DT NNS IN DT NN .',
#   <re.Match object; span=(8, 27), match='VBN DT NNS IN DT NN'>),
#  ('oh we gave water to the plant yeah ?',
#   'UH PRP VBD NN IN DT NN UH .',
#   <re.Match object; span=(7, 22), match='VBD NN IN DT NN'>),
#  ('whyontchou put them in the bucket .',
#   'NNP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('wanna put them in the sieve .',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('this session was the same day as the first session on this tape .',
#   'DT NN VBD DT JJ NN IN DT JJ NN IN DT NN .',
#   <re.Match object; span=(6, 30), match='VBD DT JJ NN IN DT JJ NN'>),
#  ("mommy's finding things in the refrigerator that's right ?",
#   'NN VBZ VBG NNS IN DT NN WDT VBZ JJ .',
#   <re.Match object; span=(3, 23), match='VBZ VBG NNS IN DT NN'>),
#  ("naima's feeding herself like a big girl .",
#   'NNP VBZ VBG PRP IN DT JJ NN .',
#   <re.Match object; span=(4, 27), match='VBZ VBG PRP IN DT JJ NN'>),
#  ('powdered sugar on it .',
#   'VBD NN IN PRP .',
#   <re.Match object; span=(0, 13), match='VBD NN IN PRP'>),
#  ('bought them for you a long time ago .',
#   'VBD PRP IN PRP DT JJ NN RB .',
#   <re.Match object; span=(0, 14), match='VBD PRP IN PRP'>),
#  ('and so i gave it to him .',
#   'CC RB PRP VBD PRP IN PRP .',
#   <re.Match object; span=(10, 24), match='VBD PRP IN PRP'>),
#  ('then he asked mike for the next one and mike gave it to him .',
#   'RB PRP VBD NNP IN DT JJ NN CC NNP VBD PRP IN PRP .',
#   <re.Match object; span=(7, 26), match='VBD NNP IN DT JJ NN'>),
#  ('and he asked mike for the third one but mike would not give him the third one until ross put the second one on the window sill also .',
#   'CC PRP VBD NNP IN DT JJ NN CC NNP MD RB VB PRP DT JJ NN IN NNP VBD DT JJ NN IN DT NN NN RB .',
#   <re.Match object; span=(7, 26), match='VBD NNP IN DT JJ NN'>),
#  ('so the third and fourth time around ross got the hang of the game .',
#   'RB DT JJ CC JJ NN RB NNP VBD DT NN IN DT NN .',
#   <re.Match object; span=(25, 43), match='VBD DT NN IN DT NN'>),
#  ('and ross just went through a lot of talking and i missed it with my taperecorder .',
#   'CC NNP RB VBD IN DT NN IN NN CC PRP VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(36, 50), match='VBD PRP IN PRP'>),
#  ("he's getting the dirt off the pig .",
#   'PRP VBZ VBG DT NN IN DT NN .',
#   <re.Match object; span=(4, 26), match='VBZ VBG DT NN IN DT NN'>),
#  ("mittens yeah that's right he put socks on his hands and they looked like mittens .",
#   'NNP UH DT VBZ JJ PRP VBD NNS IN PRP$ NNS CC PRP VBD IN NNS .',
#   <re.Match object; span=(21, 35), match='VBD NNS IN PRP'>),
#  ('then he pushed the button on his dump truck and all the sand fell out .',
#   'RB PRP VBD DT NN IN PRP$ NN NN CC PDT DT NN VBD RB .',
#   <re.Match object; span=(7, 23), match='VBD DT NN IN PRP'>),
#  ('it was a tube of miracle bubbles .',
#   'PRP VBD DT NN IN NN NNS .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('max put the bubbles in his pocket ?',
#   'NN VBD DT NNS IN PRP$ NN .',
#   <re.Match object; span=(3, 20), match='VBD DT NNS IN PRP'>),
#  ('and she put the shoes in the closet .',
#   'CC PRP VBD DT NNS IN DT NN .',
#   <re.Match object; span=(7, 26), match='VBD DT NNS IN DT NN'>),
#  ('but max found some gum and he put the gum in his pocket .',
#   'CC NNP VBD DT NN CC PRP VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(24, 40), match='VBD DT NN IN PRP'>),
#  ("and he's scooping sand inta the dump truck .",
#   'CC PRP VBZ VBG NN IN DT NN NN .',
#   <re.Match object; span=(7, 26), match='VBZ VBG NN IN DT NN'>),
#  ("yeah you've got some noodles on your clothes ?",
#   'UH PRP VBP VBN DT NNS IN PRP$ NNS .',
#   <re.Match object; span=(11, 28), match='VBN DT NNS IN PRP'>),
#  ("he's holding the toothbrush in his hands .",
#   'PRP VBZ VBG DT NN IN PRP$ NNS .',
#   <re.Match object; span=(4, 24), match='VBZ VBG DT NN IN PRP'>),
#  ("smell the bread while it bakes and the blueberry pie smell the freshly washed clothes as they're hung out to dry .",
#   'VB DT NN IN PRP VBZ CC DT NN NN VB DT RB VBN NNS IN PRP VBP VBN RP TO VB .',
#   <re.Match object; span=(41, 55), match='VBN NNS IN PRP'>),
#  ('elmo loves singing songs to the music .',
#   'NNP VBZ VBG NNS IN DT NN .',
#   <re.Match object; span=(4, 24), match='VBZ VBG NNS IN DT NN'>),
#  ('elmo loves singing songs to the music with his friends .',
#   'NNP VBZ VBG NNS IN DT NN IN PRP$ NNS .',
#   <re.Match object; span=(4, 24), match='VBZ VBG NNS IN DT NN'>),
#  ("ooh look mommy look what mommy found we haven't read this one in awhile .",
#   'UH VB NN VB WP NN VBD PRP VBP RB VBN DT NN IN NN .',
#   <re.Match object; span=(33, 48), match='VBN DT NN IN NN'>),
#  ('you read it to mommy you read it .',
#   'PRP VBD PRP IN NN PRP VBD PRP .',
#   <re.Match object; span=(4, 17), match='VBD PRP IN NN'>),
#  ('you read the book to mommy you read it .',
#   'PRP VBD DT NN IN NN PRP VBD PRP .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('mommy put ice in it too .',
#   'NN VBD NN IN PRP RB .',
#   <re.Match object; span=(3, 16), match='VBD NN IN PRP'>),
#  ('hey i think i found the other piece of the puzzle .',
#   'UH PRP VBP PRP VBD DT JJ NN IN DT NN .',
#   <re.Match object; span=(15, 36), match='VBD DT JJ NN IN DT NN'>),
#  ('he said as he absentmindedly rubbed the bump on his head .',
# ...
#  ('we saw a zebra at the zoo on saturday .',
#   'PRP VBD DT NN IN DT NN IN NNP .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('i did it for you .',
#   'PRP VBD PRP IN PRP .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('you pushed me onto the bed .',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('you pushed me onto the bed !',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('oh you did it by yourself .',
#   'UH PRP VBD PRP IN PRP .',
#   <re.Match object; span=(7, 21), match='VBD PRP IN PRP'>),
#  ("look it's the police officer he's stopping traffic so the ants can cross the street .",
#   'VB PRP VBZ DT NN NN PRP VBZ VBG NN IN DT NNS MD VB DT NN .',
#   <re.Match object; span=(24, 43), match='VBZ VBG NN IN DT NN'>),
#  ('you read it to mommy ?',
#   'PRP VBD PRP IN NN .',
#   <re.Match object; span=(4, 17), match='VBD PRP IN NN'>),
#  ("you haven't seen joey in a long time !",
#   'PRP VBP RB VBN NNP IN DT JJ NN .',
#   <re.Match object; span=(11, 30), match='VBN NNP IN DT JJ NN'>),
#  ("i've got somethin' in my mouth .",
#   'PRP VBP VBN NN IN PRP$ NN .',
#   <re.Match object; span=(8, 21), match='VBN NN IN PRP'>),
#  ("she's taking a bath with a ponytail .",
#   'PRP VBZ VBG DT NN IN DT NN .',
#   <re.Match object; span=(4, 26), match='VBZ VBG DT NN IN DT NN'>),
#  ('here sally put them in the car .',
#   'RB NNP VBD PRP IN DT NN .',
#   <re.Match object; span=(7, 23), match='VBD PRP IN DT NN'>),
#  ("he's got a big shoes on mama .",
#   'PRP VBZ VBD DT JJ NNS IN NN .',
#   <re.Match object; span=(8, 27), match='VBD DT JJ NNS IN NN'>),
#  ('daddy should have put you on the pottie .',
#   'NNP MD VB VBN PRP IN DT NN .',
#   <re.Match object; span=(10, 26), match='VBN PRP IN DT NN'>),
#  ('it has been a month since we did that ?',
#   'PRP VBZ VBN DT NN IN PRP VBD DT .',
#   <re.Match object; span=(8, 24), match='VBN DT NN IN PRP'>),
#  ('daddy squashed the door on your hand .',
#   'NNP VBD DT NN IN PRP$ NN .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ('i put them in a box on this end of the closet .',
#   'PRP VBD PRP IN DT NN IN DT NN IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('that one has got some graffiti on it !',
#   'DT NN VBZ VBN DT NN IN PRP .',
#   <re.Match object; span=(10, 26), match='VBN DT NN IN PRP'>),
#  ('you told me about it .',
#   'PRP VBD PRP IN PRP .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('i did some work down that way one time .',
#   'PRP VBD DT NN IN DT NN CD NN .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('i guess they just dug the grave and covered it so nobody falls in it .',
#   'PRP VBP PRP RB VBD DT NN CC VBD PRP IN NN VBZ IN PRP .',
#   <re.Match object; span=(28, 41), match='VBD PRP IN NN'>),
#  ('i think we skipped a page by accident .',
#   'PRP VBP PRP VBD DT NN IN NN .',
#   <re.Match object; span=(12, 27), match='VBD DT NN IN NN'>),
#  ("max pushed the red button on the space cadet's ear splitter space siren ?",
#   'NNP VBD DT JJ NN IN DT NN NN POS NN NN NN NN .',
#   <re.Match object; span=(4, 25), match='VBD DT JJ NN IN DT NN'>),
#  ("oh dear he's making a big noise with that space cadet ?",
#   'UH UH PRP VBZ VBG DT JJ NN IN DT NN NN .',
#   <re.Match object; span=(10, 35), match='VBZ VBG DT JJ NN IN DT NN'>),
#  ('max took the crown and wig off rapunzel and put them on his spider .',
#   'NNP VBD DT NN CC NN IN NNP CC VBD PRP IN PRP$ NN .',
#   <re.Match object; span=(30, 44), match='VBD PRP IN PRP'>),
#  ('uh then max put rapunzel in his own seat ?',
#   'UH RB NNP VBD NNP IN PRP$ JJ NN .',
#   <re.Match object; span=(10, 24), match='VBD NNP IN PRP'>),
#  ("di'you hit it with the rocking chair .",
#   'PRP VBD PRP IN DT NN NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ('is painting a necktie for daddy to wear .',
#   'VBZ VBG DT NN IN NN TO VB .',
#   <re.Match object; span=(0, 19), match='VBZ VBG DT NN IN NN'>),
#  ("then late at night he left them on the chicken's porch .",
#   'RB RB IN NN PRP VBD PRP IN DT NN POS NN .',
#   <re.Match object; span=(16, 32), match='VBD PRP IN DT NN'>),
#  ('i skipped a page by accident .',
#   'PRP VBD DT NN IN NN .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('luckily i stopped him before it was too late ?',
#   'RB PRP VBD PRP IN PRP VBD RB JJ .',
#   <re.Match object; span=(7, 21), match='VBD PRP IN PRP'>),
#  ('luckily i stopped him before it was too late .',
#   'RB PRP VBD PRP IN PRP VBD RB JJ .',
#   <re.Match object; span=(7, 21), match='VBD PRP IN PRP'>),
#  ("but for you i just meant today's was the last day of summer because you have school tomorrow .",
#   'CC IN PRP PRP RB VBD NN POS VBD DT JJ NN IN NN IN PRP VBP NN NN .',
#   <re.Match object; span=(28, 46), match='VBD DT JJ NN IN NN'>),
#  ("he's drinking the water in the puddle ?",
#   'PRP VBZ VBG DT NN IN DT NN .',
#   <re.Match object; span=(4, 26), match='VBZ VBG DT NN IN DT NN'>),
#  ('it i have a feeling that it from the it may you had the earphone of the cassette in the car and that it will relate to that in some way because .',
#   'PRP PRP VBP DT NN IN PRP IN DT PRP MD PRP VBD DT NN IN DT NN IN DT NN CC IN PRP MD VB IN DT IN DT NN IN .',
#   <re.Match object; span=(42, 60), match='VBD DT NN IN DT NN'>),
#  ("also we took him to the aquarium this past sunday and he's still talking about the seals .",
#   'RB PRP VBD PRP IN DT NN DT JJ NNP CC PRP VBZ RB VBG IN DT NNS .',
#   <re.Match object; span=(7, 23), match='VBD PRP IN DT NN'>),
#  ("and if he says daddy horse he's telling you that daddy took him on the merry go round .",
#   'CC IN PRP VBZ NNP NN PRP VBZ VBG PRP IN NN VBD PRP IN DT NN NN NN .',
#   <re.Match object; span=(25, 42), match='VBZ VBG PRP IN NN'>),
#  ('who drank it up the juice ?',
#   'WP VBD PRP IN DT NN .',
#   <re.Match object; span=(3, 19), match='VBD PRP IN DT NN'>),
#  ("i think you put the baby in your room didn't you nomi .",
#   'PRP VBP PRP VBD DT NN IN PRP$ NN VBD RB PRP NNP .',
#   <re.Match object; span=(12, 28), match='VBD DT NN IN PRP'>),
#  ('would you eat it if i fixed it for you ?',
#   'MD PRP VB PRP IN PRP VBD PRP IN PRP .',
#   <re.Match object; span=(21, 35), match='VBD PRP IN PRP'>),
#  ('i know you spilled it because you shook it ?',
#   'PRP VBP PRP VBD PRP IN PRP VBD PRP .',
#   <re.Match object; span=(12, 26), match='VBD PRP IN PRP'>),
#  ('you bit a hole in it ?',
#   'PRP VBD DT NN IN PRP .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ('you bit a hole in your cheese sandwich too .',
#   'PRP VBD DT NN IN PRP$ NN NN RB .',
#   <re.Match object; span=(4, 20), match='VBD DT NN IN PRP'>),
#  ('it was already broken before i put the tapioca in it ?',
#   'PRP VBD RB JJ IN PRP VBD DT NN IN PRP .',
#   <re.Match object; span=(21, 37), match='VBD DT NN IN PRP'>),
#  ('mom bit the hole in it eve .',
#   'NN VBD DT NN IN PRP NNP .',
#   <re.Match object; span=(3, 19), match='VBD DT NN IN PRP'>),
#  ('alright eve bit a hole in the dish .',
#   'UH NNP VBD DT NN IN DT NN .',
#   <re.Match object; span=(7, 25), match='VBD DT NN IN DT NN'>),
#  ('eve put the doll on the cup ?',
#   'PRP VBD DT NN IN DT NN .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('eve put the doll on the cup ?',
#   'PRP VBD DT NN IN DT NN .',
#   <re.Match object; span=(4, 22), match='VBD DT NN IN DT NN'>),
#  ('you dropped it in the cup ?',
#   'PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(4, 20), match='VBD PRP IN DT NN'>),
#  ("i closed it so you wouldn't go in there ?",
#   'PRP VBD PRP IN PRP MD RB VB RB RB .',
#   <re.Match object; span=(4, 18), match='VBD PRP IN PRP'>),
#  ('whatever gave you the idea there was a dragon in the cellar asked papa bear ?',
#   'WDT VBD PRP DT NN EX VBD DT NN IN DT NN VBN NNP NNP .',
#   <re.Match object; span=(21, 39), match='VBD DT NN IN DT NN'>),
#  ('i thought we had elephants with byebyes ?',
#   'PRP VBD PRP VBD NNS IN NNS .',
#   <re.Match object; span=(12, 25), match='VBD NNS IN NN'>),
#  ('where did the penguins with sunglasses go ?',
#   'WRB VBD DT NNS IN NNS VB .',
#   <re.Match object; span=(4, 20), match='VBD DT NNS IN NN'>),
#  ('tadi drew a card for dada with nannie .',
#   'NNP VBD DT NN IN NNP IN NNP .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('i think you left yours on the kitchen floor .',
#   'PRP VBP PRP VBD PRP IN DT NN NN .',
#   <re.Match object; span=(12, 28), match='VBD PRP IN DT NN'>),
#  ('but i bought it for christmas .',
#   'CC PRP VBD PRP IN NNP .',
#   <re.Match object; span=(7, 20), match='VBD PRP IN NN'>),
#  ('oh you put some tape on the slide alright .',
#   'UH PRP VBD DT NN IN DT NN UH .',
#   <re.Match object; span=(7, 25), match='VBD DT NN IN DT NN'>),
#  ('i think you hit yourself in the head .',
#   'PRP VBP PRP VBD PRP IN DT NN .',
#   <re.Match object; span=(12, 28), match='VBD PRP IN DT NN'>),
#  ('the lion was the king of the jungle .',
#   'DT NN VBD DT NN IN DT NN .',
#   <re.Match object; span=(6, 24), match='VBD DT NN IN DT NN'>),
#  ("oh you've got a moon on the stamp .",
#   'UH PRP VBP VBN DT NN IN DT NN .',
#   <re.Match object; span=(11, 29), match='VBN DT NN IN DT NN'>),
#  ("you've got a lot of pictures on the sheet don't you .",
#   'PRP VBP VBN DT NN IN NNS IN DT NN VBP RB PRP .',
#   <re.Match object; span=(8, 23), match='VBN DT NN IN NN'>),
#  ('when miffy had tired of her play the bunny family had a drink of orange juice and then when home for tea ?',
#   'WRB NNP VBD VBN IN PRP$ NN DT NNP NN VBD DT NN IN NN NN CC RB WRB RB IN NN .',
#   <re.Match object; span=(37, 52), match='VBD DT NN IN NN'>),
#  ('close your eyes said frederick as he climbed on a big stone i send you the rays of sun .',
#   'VB PRP$ NNS VBD NNP IN PRP VBD IN DT JJ NN PRP VBP PRP DT NNS IN NN .',
#   <re.Match object; span=(12, 26), match='VBD NNP IN PRP'>),
#  ('and what about the colors frederick close your eyes again he said and he told them of the blue periwinkles the red poppies and the yellow wheat and the green leaves of the berry bush .',
#   'CC WP IN DT NNS NNP VB PRP$ NNS RB PRP VBD CC PRP VBD PRP IN DT JJ NNS DT JJ NNS CC DT JJ NN CC DT JJ NNS IN DT NN NN .',
#   <re.Match object; span=(50, 69), match='VBD PRP IN DT JJ NN'>),
#  ('my mom found them for me in new york and i love them .',
#   'PRP$ NN VBD PRP IN PRP IN NNP NNP CC PRP VBP PRP .',
#   <re.Match object; span=(8, 22), match='VBD PRP IN PRP'>),
#  ('peering outside she sipped tea from her cup and eagerly watched for the sun to come .',
#   'VBG RB PRP VBD NN IN PRP$ NN CC RB VBD IN DT NN TO VB .',
#   <re.Match object; span=(11, 24), match='VBD NN IN PRP'>),
#  ('she was sitting in her high chair and then she said she wanted to sit next to me so i put her in the booth next to me and she stood up and she stood up and i was like lily you better sit down and she wah fell right down ?',
#   'PRP VBD VBG IN PRP$ JJ NN CC RB PRP VBD PRP VBD TO VB RB IN PRP CC PRP VBD PRP IN DT NN RB IN PRP CC PRP VBD RP CC PRP VBD RP CC PRP VBD UH NNP PRP RBR VB RP CC PRP UH VBD RB RB .',
#   <re.Match object; span=(71, 87), match='VBD PRP IN DT NN'>),
#  ('oh no the ball went splash in the water ?',
#   'UH UH DT NN VBD NN IN DT NN .',
#   <re.Match object; span=(12, 27), match='VBD NN IN DT NN'>),
#  ("it was so easy we got it at billy's factory store it's in fall river it was like i think the whole i think the piece was like one hundred and twenty five dollars maybe .",
#   'PRP VBD RB JJ PRP VBD PRP IN NNP POS NNP NNP PRP VBZ IN NNP NNP PRP VBD UH PRP VBP DT NN PRP VBP DT NN VBD UH CD CD CC CD CD NNS RB .',
#   <re.Match object; span=(18, 31), match='VBD PRP IN NN'>),
#  ('and um they are yummy the sweet and sour ones have dried pineapple in them .',
#   'CC UH PRP VBP JJ DT JJ CC JJ NNS VBP VBN NN IN PRP .',
#   <re.Match object; span=(37, 50), match='VBN NN IN PRP'>),
#  ("that girl is finding the rubber duck to give it to the pig who's taking a bath with bubbles in the bath tub .",
#   'DT NN VBZ VBG DT NN NN TO VB PRP IN DT NN WP VBZ VBG DT NN IN NNS IN DT NN NN .',
#   <re.Match object; span=(45, 64), match='VBZ VBG DT NN IN NN'>),
#  ('shh shh shh shh shh that pig made a big mess she wanted all kinds of things .',
#   'UH UH UH UH UH DT NN VBD DT JJ NN PRP VBD DT NNS IN NNS .',
#   <re.Match object; span=(38, 54), match='VBD DT NNS IN NN'>),
#  ("she's using some glue on a brush .",
#   'PRP VBZ VBG DT NN IN DT NN .',
#   <re.Match object; span=(4, 26), match='VBZ VBG DT NN IN DT NN'>),
#  ("yeah she's stamping envelopes and then she's taking them to the post office in a what .",
#   'UH PRP VBZ VBG NNS CC RB PRP VBZ VBG PRP IN DT NN NN IN DT WP .',
#   <re.Match object; span=(29, 49), match='VBZ VBG PRP IN DT NN'>),
#  ("ah where you know where's your hammer i haven't seen it for a while .",
#   'UH WRB PRP VBP WRB VBZ PRP$ NN PRP VBP RB VBN PRP IN DT NN .',
#   <re.Match object; span=(42, 58), match='VBN PRP IN DT NN'>),
#  ('glenmae is wearing something around her neck .',
#   'NNP VBZ VBG NN IN PRP$ NN .',
#   <re.Match object; span=(4, 21), match='VBZ VBG NN IN PRP'>),
#  ('they all have necklaces well the goat is wearing a bell around her neck glenmae is wearing a necklace around her neck .',
#   'PRP DT VBP NNS UH DT NN VBZ VBG DT NN IN PRP$ NN NNP VBZ VBG DT NN IN PRP$ NN .',
#   <re.Match object; span=(24, 44), match='VBZ VBG DT NN IN PRP'>),
#  ("she's watching her because she's little ah .",
#   'PRP VBZ VBG PRP IN PRP VBZ JJ UH .',
#   <re.Match object; span=(4, 22), match='VBZ VBG PRP IN PRP'>),
#  ("the goat is peeking over glenmae's shoulder while she's pounding the roots with that mallet .",
#   'DT NN VBZ VBG IN NNP POS NN IN PRP VBZ VBG DT NNS IN DT NN .',
#   <re.Match object; span=(35, 58), match='VBZ VBG DT NNS IN DT NN'>),
#  ("she's washing it with her hands and a bucket .",
#   'PRP VBZ VBG PRP IN PRP$ NNS CC DT NN .',
#   <re.Match object; span=(4, 22), match='VBZ VBG PRP IN PRP'>),
#  ('she is brushing it with a blue brush and she has a black comb also ?',
#   'PRP VBZ VBG PRP IN DT JJ NN CC PRP VBZ DT JJ NN RB .',
#   <re.Match object; span=(4, 27), match='VBZ VBG PRP IN DT JJ NN'>),
#  ("mhm and that says max pushed the red button on the space cadet's splitter space siren ?",
#   'UH CC DT VBZ NNP VBD DT JJ NN IN DT NN NN POS NN NN NN .',
#   <re.Match object; span=(17, 38), match='VBD DT JJ NN IN DT NN'>),
#  ("looks like he's lifting the slug in the chair .",
#   'VBZ IN PRP VBZ VBG DT NN IN DT NN .',
#   <re.Match object; span=(11, 33), match='VBZ VBG DT NN IN DT NN'>),
#  ('max took his ear splitter space cadet and dressed him in mrs quacks .',
#   'NNP VBD PRP$ NN NN NN NN CC VBD PRP IN NNP NNP .',
#   <re.Match object; span=(28, 41), match='VBD PRP IN NN'>),
#  ('max introduced grandma to the jelly ball shooter spider and the ear splitter space ?',
#   'NNP VBD NN IN DT NN NN NN NN CC DT NN NN NN .',
#   <re.Match object; span=(4, 19), match='VBD NN IN DT NN'>),
#  ('you had a piece of gum with andy ?',
#   'PRP VBD DT NN IN NN IN NNP .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('i took laura with me when i went to disneyland .',
#   'PRP VBD NNP IN PRP WRB PRP VBD IN NNP .',
#   <re.Match object; span=(4, 18), match='VBD NNP IN PRP'>),
#  ('what was the matter with maddy ?',
#   'WP VBD DT NN IN NNP .',
#   <re.Match object; span=(3, 18), match='VBD DT NN IN NN'>),
#  ("got lots of buttons doesn't it .",
#   'VBD NNS IN NNS VBZ RB PRP .',
#   <re.Match object; span=(0, 13), match='VBD NNS IN NN'>),
#  ('perhaps you would not be grumpy if you went sailing said the man with the polka dot tie .',
#   'RB PRP MD RB VB JJ IN PRP VBD NN VBD DT NN IN DT NN NN NN .',
#   <re.Match object; span=(33, 51), match='VBD DT NN IN DT NN'>),
#  ('he filled the bathtub with water .',
#   'PRP VBD DT NN IN NN .',
#   <re.Match object; span=(4, 19), match='VBD DT NN IN NN'>),
#  ('the next day the man with the polka dot tie and his little boy carried scuffy to a river .',
#   'DT JJ NN DT NN IN DT JJ NN NN CC PRP$ JJ NN VBD NNP IN DT NN .',
#   <re.Match object; span=(44, 60), match='VBD NNP IN DT NN'>),
#  ('sail little tugboat said the man with the polka dot tie .',
#   'JJ JJ NN VBD DT NN IN DT NN NN NN .',
#   <re.Match object; span=(9, 27), match='VBD DT NN IN DT NN'>),
#  ...]
