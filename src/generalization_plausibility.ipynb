# %%
import utils

# %%
generalization_sents = utils.read_json("../data/experiments/sentences/generalization.json")

# %%
for k, v in generalization_sents.items():
    print(k)
    for kk, vv in v.items():
        print(f"{kk}: {vv[0]}")
# Out:
# paspas
# do: they [verb] him us .
# pp: they [verb] us to him .
# paspis
# do: the cat [verb] it us .
# pp: the cat [verb] us to it .
# pasnal
# do: the puppy [verb] the small baby us .
# pp: the puppy [verb] us to the small baby .
# pasnas
# do: the toys [verb] pooh him .
# pp: the toys [verb] him to pooh .
# pasnil
# do: the cat [verb] a bit of the milk him .
# pp: the cat [verb] him to a bit of the milk .
# pasnis
# do: they [verb] the soup us .
# pp: they [verb] us to the soup .
# pispas
# do: the baby [verb] us it .
# pp: the baby [verb] it to us .
# pisnal
# do: the puppy [verb] the cute baby it .
# pp: the puppy [verb] it to the cute baby .
# pisnas
# do: david [verb] daddy it .
# pp: david [verb] it to daddy .
# pisnil
# do: the car [verb] a few toys it .
# pp: the car [verb] it to a few toys .
# pisnis
# do: the cat [verb] the book it .
# pp: the cat [verb] it to the book .
# nalpas
# do: they [verb] him the small baby .
# pp: they [verb] the small baby to him .
# nalpis
# ...
